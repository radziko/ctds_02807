# %% [markdown]
# # Min Hashing

# %%
#!pip install kagglehub
import kagglehub
import os
import shutil
from urllib.request import urlretrieve
import numpy as np
import pandas as pd
from tqdm.notebook import tqdm
import pickle

from datasketch import MinHash, MinHashLSH

# %%
def load_data():
    # Contains movieId, title, genres   
    ml_movies = pd.read_csv('data/ml-32m/movies.csv')
    
    # Contains userId, movieId, rating, timestamp
    ml_ratings = pd.read_csv('data/ml-32m/ratings.csv')
    
    # Contains userId, movieId, tag, timestamp
    ml_tags = pd.read_csv('data/ml-32m/tags.csv')

    # Contains movieId, imdbId, tmdbId
    ml_links = pd.read_csv('data/ml-32m/links.csv')

    # IMDB Dataset:
    imdb = pd.read_csv('data/imdb/movies.csv')

    return ml_movies, ml_ratings, ml_tags, ml_links, imdb

ml_movies, ml_ratings, ml_tags, ml_links, imdb = load_data()
# Out:
# /var/folders/0l/26n95fy50m782tbz32d5_1g40000gn/T/ipykernel_39571/683732697.py:15: DtypeWarning: Columns (7,8) have mixed types. Specify dtype option on import or set low_memory=False.
#   imdb = pd.read_csv('data/imdb/movies.csv')

# %%
# Preprocessing IMDB:

#drop if description is "Add a plot" because we have no description then
imdb_descriptions = imdb[imdb['description'] != "Add a Plot"]

imdb_descriptions['id'] = imdb_descriptions['id'].str[2:]
imdb_descriptions['id'] = pd.to_numeric(imdb_descriptions['id'], errors='coerce')

#keep what we need
imdb_descriptions = imdb_descriptions[['id', 'description']]

#merge them, so we have a li nk between the two datasets
merged_links = ml_links.merge(imdb_descriptions, left_on='imdbId', right_on='id', how='inner').dropna(subset=['id'])
# Out:
# /var/folders/0l/26n95fy50m782tbz32d5_1g40000gn/T/ipykernel_39571/493108502.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   imdb_descriptions['id'] = imdb_descriptions['id'].str[2:]
# /var/folders/0l/26n95fy50m782tbz32d5_1g40000gn/T/ipykernel_39571/493108502.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   imdb_descriptions['id'] = pd.to_numeric(imdb_descriptions['id'], errors='coerce')

# %%
#merge the movies with the descriptions if that is what we want
ml_movies_description = ml_movies.merge(merged_links, left_on='movieId', right_on='movieId', how='inner')

ml_movies_description
# Out:
#        movieId                        title  \
# 0            1             Toy Story (1995)
# 1            2               Jumanji (1995)
# 2            6                  Heat (1995)
# 3            8          Tom and Huck (1995)
# 4            9          Sudden Death (1995)
# ...        ...                          ...
# 51855   292541          The Settlers (2023)
# 51856   292585        Night Crawlers (2009)
# 51857   292605  Our River... Our Sky (2023)
# 51858   292613             Freelance (2023)
# 51859   292627     All Fun and Games (2023)
#
#                                             genres    imdbId    tmdbId  \
# 0      Adventure|Animation|Children|Comedy|Fantasy    114709     862.0
# 1                       Adventure|Children|Fantasy    113497    8844.0
# 2                            Action|Crime|Thriller    113277     949.0
# 3                               Adventure|Children    112302   45325.0
# 4                                           Action    114576    9091.0
# ...                                            ...       ...       ...
# 51855                                Drama|Western  10370812  989589.0
# 51856                                Comedy|Horror    985060  147230.0
# 51857                                    Drama|War  10676126  855800.0
# 51858                                Action|Comedy  15744298  897087.0
# 51859                              Horror|Thriller  10092698  926599.0
#
#              id                                        description
# 0        114709  A cowboy doll is profoundly threatened and jea...
# 1        113497  When two kids find and play a magical board ga...
# 2        113277  A group of high-end professional thieves start...
# 3        112302  Two best friends witness a murder and embark o...
# 4        114576  A former fireman takes on a group of terrorist...
# ...         ...                                                ...
# 51855  10370812  A mixed-race Chilean, rides south on an expedi...
# 51856    985060  Blood is thicker than water in this tiny Texas...
# 51857  10676126  Baghdad. The last week of 2006. All over the c...
# 51858  15744298  An ex special forces operator takes a job to p...
# 51859  10092698  There's a strange element of cruelty that's em...
#
# [51860 rows x 7 columns]

# %% [markdown]
# ### Min-hashing

# %%
num_perm = 128

# %%
def run_or_read_minhash(run: bool, df, num_perm=num_perm):
# Sample DataFrame setup
# df = pd.DataFrame({'description': [...]})
    if run:
        # Define a function to min-hash a description
        def minhash_description(text, num_perm=num_perm):
            m = MinHash(num_perm=num_perm)
            for word in text.split():
                m.update(word.encode('utf8'))
            return m

        # Apply min-hashing on the 'description' column
        df['minhash'] = df['description'].apply(minhash_description)

        # (Optional) Convert min-hash signatures to a comparable format
        df['minhash_signature'] = df['minhash'].apply(lambda x: x.digest())

        df.to_pickle('data/df_min_hash.pkl')
        print('Minhashing done and saved to df_min_hash.pkl')
    else:
        df = pd.read_pickle('data/df_min_hash.pkl')
        print('Minhashing loaded from df_min_hash.pkl')
    return df

# %%
df_small = ml_movies_description
df_minhash = run_or_read_minhash(False, df_small, num_perm=num_perm)
# Out:
# Minhashing loaded from df_min_hash.pkl

# %% [markdown]
# ### LSH

# %%
threshold = 0.4

# %%
def run_or_read_lsh(run: bool, df_minhash, threshold, num_perm=num_perm):

    if run:
        lsh = MinHashLSH(threshold=threshold, num_perm=num_perm)

        # Insert each min-hash signature into the LSH
        for idx, minhash in enumerate(df_minhash['minhash']):
            lsh.insert(idx, minhash)  # Use the DataFrame index as the unique ID

        # Function to find similar items using LSH
        def find_similar(description, lsh, num_perm=128):
            m = MinHash(num_perm=num_perm)
            for word in description.split():
                m.update(word.encode('utf8'))
            return lsh.query(m)

        # save similaritities to dict
        bands = {}
        for idx in tqdm(range(len(df_minhash))):
            bands[idx] = find_similar(df_minhash['description'][idx], lsh)

        # save similarities to file as pickle
        with open(f'data/lsh_groups_{threshold}.pkl', 'wb') as f:
            pickle.dump(bands, f)
        print('LSH done and saved to lsh_groups.pkl')
    else:
        with open(f'data/lsh_groups_{threshold}.pkl', 'rb') as f:
            bands = pickle.load(f)
        print('LSH loaded from lsh_groups.pkl')
    return bands

# %%
dict_lsh = run_or_read_lsh(True, df_minhash, threshold=threshold, num_perm=num_perm)
# Out:
# 100%|██████████| 51860/51860 [00:57<00:00, 902.58it/s]
# LSH done and saved to lsh_groups.pkl

# %%
# calculate jaccard for second band (df_lsh[1])

def jaccard_similarity(s1, s2):
    return len(s1.intersection(s2)) / len(s1.union(s2))

for idx in dict_lsh[1]:
    jaccard_score = df_minhash['minhash'][1].jaccard(df_minhash['minhash'][idx])
    print(f'Jaccard similarity between 1 and {idx}: {jaccard_score}')
# Out:
# Jaccard similarity between 1 and 1: 1.0
# Jaccard similarity between 1 and 32775: 0.0859375
# Jaccard similarity between 1 and 11: 0.078125
# Jaccard similarity between 1 and 13: 0.078125
# Jaccard similarity between 1 and 32788: 0.0390625
# Jaccard similarity between 1 and 20: 0.125
# Jaccard similarity between 1 and 32790: 0.046875
# Jaccard similarity between 1 and 25: 0.0859375
# Jaccard similarity between 1 and 32797: 0.0703125
# Jaccard similarity between 1 and 32802: 0.0625
# Jaccard similarity between 1 and 32806: 0.1015625
# Jaccard similarity between 1 and 32825: 0.0859375
# Jaccard similarity between 1 and 32829: 0.125
# Jaccard similarity between 1 and 32830: 0.109375
# Jaccard similarity between 1 and 32833: 0.078125
# Jaccard similarity between 1 and 32837: 0.0859375
# Jaccard similarity between 1 and 32840: 0.0703125
# Jaccard similarity between 1 and 79: 0.1015625
# Jaccard similarity between 1 and 81: 0.0625
# Jaccard similarity between 1 and 83: 0.0625
# Jaccard similarity between 1 and 86: 0.109375
# Jaccard similarity between 1 and 32864: 0.0703125
# Jaccard similarity between 1 and 32867: 0.1015625
# Jaccard similarity between 1 and 32876: 0.0703125
# Jaccard similarity between 1 and 32877: 0.125
# Jaccard similarity between 1 and 32887: 0.0859375
# Jaccard similarity between 1 and 129: 0.0859375
# Jaccard similarity between 1 and 134: 0.1171875
# Jaccard similarity between 1 and 136: 0.0703125
# Jaccard similarity between 1 and 32904: 0.0703125
# Jaccard similarity between 1 and 139: 0.1328125
# Jaccard similarity between 1 and 32911: 0.0625
# Jaccard similarity between 1 and 32912: 0.109375
# Jaccard similarity between 1 and 32916: 0.0625
# Jaccard similarity between 1 and 32918: 0.078125
# Jaccard similarity between 1 and 32919: 0.0859375
# Jaccard similarity between 1 and 152: 0.078125
# Jaccard similarity between 1 and 154: 0.1484375
# Jaccard similarity between 1 and 159: 0.0546875
# Jaccard similarity between 1 and 171: 0.1328125
# Jaccard similarity between 1 and 172: 0.1015625
# Jaccard similarity between 1 and 174: 0.078125
# Jaccard similarity between 1 and 32952: 0.0703125
# Jaccard similarity between 1 and 189: 0.0625
# Jaccard similarity between 1 and 32958: 0.125
# Jaccard similarity between 1 and 195: 0.109375
# Jaccard similarity between 1 and 32966: 0.1171875
# Jaccard similarity between 1 and 199: 0.078125
# Jaccard similarity between 1 and 32967: 0.109375
# Jaccard similarity between 1 and 32981: 0.09375
# Jaccard similarity between 1 and 217: 0.09375
# Jaccard similarity between 1 and 32985: 0.09375
# Jaccard similarity between 1 and 32987: 0.1171875
# Jaccard similarity between 1 and 32991: 0.046875
# Jaccard similarity between 1 and 32993: 0.046875
# Jaccard similarity between 1 and 231: 0.0625
# Jaccard similarity between 1 and 33000: 0.0703125
# Jaccard similarity between 1 and 33005: 0.0625
# Jaccard similarity between 1 and 33010: 0.0703125
# Jaccard similarity between 1 and 33015: 0.109375
# Jaccard similarity between 1 and 33016: 0.046875
# Jaccard similarity between 1 and 249: 0.0703125
# Jaccard similarity between 1 and 250: 0.046875
# Jaccard similarity between 1 and 33029: 0.078125
# Jaccard similarity between 1 and 266: 0.0625
# Jaccard similarity between 1 and 268: 0.0859375
# Jaccard similarity between 1 and 33043: 0.0234375
# Jaccard similarity between 1 and 33052: 0.0703125
# Jaccard similarity between 1 and 33054: 0.0703125
# Jaccard similarity between 1 and 287: 0.1171875
# Jaccard similarity between 1 and 33056: 0.0390625
# Jaccard similarity between 1 and 33075: 0.046875
# Jaccard similarity between 1 and 308: 0.0390625
# Jaccard similarity between 1 and 314: 0.109375
# Jaccard similarity between 1 and 327: 0.0859375
# Jaccard similarity between 1 and 332: 0.109375
# Jaccard similarity between 1 and 33105: 0.109375
# Jaccard similarity between 1 and 33110: 0.0703125
# Jaccard similarity between 1 and 33113: 0.09375
# Jaccard similarity between 1 and 346: 0.1796875
# Jaccard similarity between 1 and 33115: 0.0703125
# Jaccard similarity between 1 and 33117: 0.0546875
# Jaccard similarity between 1 and 359: 0.0625
# Jaccard similarity between 1 and 33127: 0.1171875
# Jaccard similarity between 1 and 368: 0.078125
# Jaccard similarity between 1 and 383: 0.109375
# Jaccard similarity between 1 and 385: 0.1015625
# Jaccard similarity between 1 and 33172: 0.1015625
# Jaccard similarity between 1 and 33175: 0.0859375
# Jaccard similarity between 1 and 33176: 0.125
# Jaccard similarity between 1 and 33177: 0.03125
# Jaccard similarity between 1 and 33194: 0.09375
# Jaccard similarity between 1 and 33195: 0.0859375
# Jaccard similarity between 1 and 428: 0.140625
# Jaccard similarity between 1 and 33198: 0.1015625
# Jaccard similarity between 1 and 33200: 0.09375
# Jaccard similarity between 1 and 33209: 0.0234375
# Jaccard similarity between 1 and 33214: 0.0625
# Jaccard similarity between 1 and 447: 0.078125
# Jaccard similarity between 1 and 33218: 0.0546875
# Jaccard similarity between 1 and 33228: 0.125
# Jaccard similarity between 1 and 33233: 0.109375
# Jaccard similarity between 1 and 466: 0.0703125
# Jaccard similarity between 1 and 33255: 0.15625
# Jaccard similarity between 1 and 33266: 0.0625
# Jaccard similarity between 1 and 33270: 0.0703125
# Jaccard similarity between 1 and 504: 0.125
# Jaccard similarity between 1 and 505: 0.078125
# Jaccard similarity between 1 and 33273: 0.0625
# Jaccard similarity between 1 and 508: 0.078125
# Jaccard similarity between 1 and 33278: 0.078125
# Jaccard similarity between 1 and 33281: 0.0703125
# Jaccard similarity between 1 and 33288: 0.078125
# Jaccard similarity between 1 and 520: 0.09375
# Jaccard similarity between 1 and 33293: 0.0703125
# Jaccard similarity between 1 and 537: 0.0390625
# Jaccard similarity between 1 and 540: 0.109375
# Jaccard similarity between 1 and 33312: 0.109375
# Jaccard similarity between 1 and 33318: 0.125
# Jaccard similarity between 1 and 33320: 0.0546875
# Jaccard similarity between 1 and 33322: 0.09375
# Jaccard similarity between 1 and 558: 0.0625
# Jaccard similarity between 1 and 33328: 0.140625
# Jaccard similarity between 1 and 570: 0.0546875
# Jaccard similarity between 1 and 582: 0.078125
# Jaccard similarity between 1 and 33350: 0.03125
# Jaccard similarity between 1 and 585: 0.0703125
# Jaccard similarity between 1 and 590: 0.03125
# Jaccard similarity between 1 and 592: 0.0859375
# Jaccard similarity between 1 and 33360: 0.125
# Jaccard similarity between 1 and 595: 0.0859375
# Jaccard similarity between 1 and 598: 0.0859375
# Jaccard similarity between 1 and 33373: 0.1171875
# Jaccard similarity between 1 and 33374: 0.0625
# Jaccard similarity between 1 and 33379: 0.0625
# Jaccard similarity between 1 and 612: 0.09375
# Jaccard similarity between 1 and 33383: 0.0546875
# Jaccard similarity between 1 and 633: 0.125
# Jaccard similarity between 1 and 33401: 0.078125
# Jaccard similarity between 1 and 640: 0.1328125
# Jaccard similarity between 1 and 643: 0.1171875
# Jaccard similarity between 1 and 661: 0.03125
# Jaccard similarity between 1 and 663: 0.0859375
# Jaccard similarity between 1 and 664: 0.0625
# Jaccard similarity between 1 and 33431: 0.109375
# Jaccard similarity between 1 and 33432: 0.0859375
# Jaccard similarity between 1 and 667: 0.1015625
# Jaccard similarity between 1 and 669: 0.046875
# Jaccard similarity between 1 and 671: 0.09375
# Jaccard similarity between 1 and 679: 0.09375
# Jaccard similarity between 1 and 681: 0.1171875
# Jaccard similarity between 1 and 683: 0.046875
# Jaccard similarity between 1 and 33459: 0.015625
# Jaccard similarity between 1 and 33460: 0.03125
# Jaccard similarity between 1 and 691: 0.0546875
# Jaccard similarity between 1 and 33465: 0.078125
# Jaccard similarity between 1 and 697: 0.046875
# Jaccard similarity between 1 and 33466: 0.046875
# Jaccard similarity between 1 and 702: 0.0390625
# Jaccard similarity between 1 and 33471: 0.0703125
# Jaccard similarity between 1 and 707: 0.0625
# Jaccard similarity between 1 and 721: 0.0859375
# Jaccard similarity between 1 and 33492: 0.0859375
# Jaccard similarity between 1 and 733: 0.0859375
# Jaccard similarity between 1 and 33502: 0.0859375
# Jaccard similarity between 1 and 33505: 0.078125
# Jaccard similarity between 1 and 33506: 0.1875
# Jaccard similarity between 1 and 33509: 0.046875
# Jaccard similarity between 1 and 744: 0.09375
# Jaccard similarity between 1 and 33515: 0.0546875
# Jaccard similarity between 1 and 33516: 0.0625
# Jaccard similarity between 1 and 33518: 0.1015625
# Jaccard similarity between 1 and 33529: 0.1328125
# Jaccard similarity between 1 and 33536: 0.0703125
# Jaccard similarity between 1 and 33543: 0.09375
# Jaccard similarity between 1 and 781: 0.0546875
# Jaccard similarity between 1 and 786: 0.1171875
# Jaccard similarity between 1 and 33555: 0.0703125
# Jaccard similarity between 1 and 33568: 0.109375
# Jaccard similarity between 1 and 801: 0.046875
# Jaccard similarity between 1 and 802: 0.078125
# Jaccard similarity between 1 and 805: 0.140625
# Jaccard similarity between 1 and 33577: 0.0625
# Jaccard similarity between 1 and 33581: 0.03125
# Jaccard similarity between 1 and 829: 0.125
# Jaccard similarity between 1 and 33599: 0.0625
# Jaccard similarity between 1 and 33602: 0.1171875
# Jaccard similarity between 1 and 835: 0.0859375
# Jaccard similarity between 1 and 836: 0.0859375
# Jaccard similarity between 1 and 33604: 0.1171875
# Jaccard similarity between 1 and 33606: 0.0859375
# Jaccard similarity between 1 and 33610: 0.046875
# Jaccard similarity between 1 and 33611: 0.1015625
# Jaccard similarity between 1 and 847: 0.1015625
# Jaccard similarity between 1 and 33617: 0.078125
# Jaccard similarity between 1 and 850: 0.046875
# Jaccard similarity between 1 and 33618: 0.1171875
# Jaccard similarity between 1 and 33620: 0.0625
# Jaccard similarity between 1 and 863: 0.0703125
# Jaccard similarity between 1 and 866: 0.0859375
# Jaccard similarity between 1 and 875: 0.046875
# Jaccard similarity between 1 and 33646: 0.203125
# Jaccard similarity between 1 and 33648: 0.09375
# Jaccard similarity between 1 and 33653: 0.0859375
# Jaccard similarity between 1 and 890: 0.09375
# Jaccard similarity between 1 and 33659: 0.078125
# Jaccard similarity between 1 and 891: 0.125
# Jaccard similarity between 1 and 33662: 0.1015625
# Jaccard similarity between 1 and 903: 0.1015625
# Jaccard similarity between 1 and 908: 0.1171875
# Jaccard similarity between 1 and 33677: 0.109375
# Jaccard similarity between 1 and 33679: 0.0625
# Jaccard similarity between 1 and 33682: 0.0390625
# Jaccard similarity between 1 and 915: 0.0703125
# Jaccard similarity between 1 and 917: 0.0546875
# Jaccard similarity between 1 and 33688: 0.078125
# Jaccard similarity between 1 and 926: 0.0625
# Jaccard similarity between 1 and 33703: 0.1015625
# Jaccard similarity between 1 and 33704: 0.1328125
# Jaccard similarity between 1 and 33724: 0.0859375
# Jaccard similarity between 1 and 958: 0.1171875
# Jaccard similarity between 1 and 960: 0.0703125
# Jaccard similarity between 1 and 33733: 0.0546875
# Jaccard similarity between 1 and 33738: 0.046875
# Jaccard similarity between 1 and 33742: 0.0703125
# Jaccard similarity between 1 and 33748: 0.046875
# Jaccard similarity between 1 and 33749: 0.171875
# Jaccard similarity between 1 and 33752: 0.03125
# Jaccard similarity between 1 and 33753: 0.046875
# Jaccard similarity between 1 and 33754: 0.078125
# Jaccard similarity between 1 and 987: 0.0625
# Jaccard similarity between 1 and 33758: 0.1328125
# Jaccard similarity between 1 and 33762: 0.09375
# Jaccard similarity between 1 and 995: 0.140625
# Jaccard similarity between 1 and 33767: 0.0859375
# Jaccard similarity between 1 and 33774: 0.0546875
# Jaccard similarity between 1 and 33775: 0.0625
# Jaccard similarity between 1 and 1017: 0.109375
# Jaccard similarity between 1 and 33794: 0.0859375
# Jaccard similarity between 1 and 1028: 0.0703125
# Jaccard similarity between 1 and 33796: 0.15625
# Jaccard similarity between 1 and 33803: 0.125
# Jaccard similarity between 1 and 33811: 0.078125
# Jaccard similarity between 1 and 33812: 0.0546875
# Jaccard similarity between 1 and 33816: 0.0390625
# Jaccard similarity between 1 and 33819: 0.078125
# Jaccard similarity between 1 and 33822: 0.0546875
# Jaccard similarity between 1 and 1063: 0.03125
# Jaccard similarity between 1 and 33836: 0.03125
# Jaccard similarity between 1 and 1069: 0.0703125
# Jaccard similarity between 1 and 33838: 0.1015625
# Jaccard similarity between 1 and 33846: 0.046875
# Jaccard similarity between 1 and 33849: 0.0859375
# Jaccard similarity between 1 and 33860: 0.09375
# Jaccard similarity between 1 and 1095: 0.0625
# Jaccard similarity between 1 and 33867: 0.0625
# Jaccard similarity between 1 and 1100: 0.046875
# Jaccard similarity between 1 and 33869: 0.078125
# Jaccard similarity between 1 and 1105: 0.0546875
# Jaccard similarity between 1 and 33887: 0.0703125
# Jaccard similarity between 1 and 33892: 0.046875
# Jaccard similarity between 1 and 33893: 0.09375
# Jaccard similarity between 1 and 1128: 0.0390625
# Jaccard similarity between 1 and 1138: 0.078125
# Jaccard similarity between 1 and 33908: 0.109375
# Jaccard similarity between 1 and 1146: 0.0390625
# Jaccard similarity between 1 and 1165: 0.1015625
# Jaccard similarity between 1 and 1166: 0.0625
# Jaccard similarity between 1 and 33934: 0.0546875
# Jaccard similarity between 1 and 1173: 0.09375
# Jaccard similarity between 1 and 33941: 0.125
# Jaccard similarity between 1 and 1176: 0.1015625
# Jaccard similarity between 1 and 33951: 0.0859375
# Jaccard similarity between 1 and 1189: 0.125
# Jaccard similarity between 1 and 33963: 0.078125
# Jaccard similarity between 1 and 1197: 0.0859375
# Jaccard similarity between 1 and 33965: 0.078125
# Jaccard similarity between 1 and 33969: 0.1015625
# Jaccard similarity between 1 and 33974: 0.0546875
# Jaccard similarity between 1 and 33976: 0.125
# Jaccard similarity between 1 and 33987: 0.0859375
# Jaccard similarity between 1 and 1228: 0.0859375
# Jaccard similarity between 1 and 1229: 0.15625
# Jaccard similarity between 1 and 1230: 0.078125
# Jaccard similarity between 1 and 1231: 0.0859375
# Jaccard similarity between 1 and 33996: 0.09375
# Jaccard similarity between 1 and 1236: 0.1015625
# Jaccard similarity between 1 and 34008: 0.1015625
# Jaccard similarity between 1 and 34021: 0.0703125
# Jaccard similarity between 1 and 34026: 0.1015625
# Jaccard similarity between 1 and 1267: 0.1328125
# Jaccard similarity between 1 and 34043: 0.109375
# Jaccard similarity between 1 and 34044: 0.1015625
# Jaccard similarity between 1 and 34053: 0.078125
# Jaccard similarity between 1 and 34054: 0.0546875
# Jaccard similarity between 1 and 1297: 0.1015625
# Jaccard similarity between 1 and 34069: 0.0625
# Jaccard similarity between 1 and 34077: 0.078125
# Jaccard similarity between 1 and 1310: 0.1484375
# Jaccard similarity between 1 and 1314: 0.09375
# Jaccard similarity between 1 and 34085: 0.0703125
# Jaccard similarity between 1 and 1323: 0.1015625
# Jaccard similarity between 1 and 34092: 0.109375
# Jaccard similarity between 1 and 34094: 0.03125
# Jaccard similarity between 1 and 1342: 0.0546875
# Jaccard similarity between 1 and 34111: 0.0625
# Jaccard similarity between 1 and 34118: 0.0859375
# Jaccard similarity between 1 and 34120: 0.1015625
# Jaccard similarity between 1 and 34127: 0.140625
# Jaccard similarity between 1 and 34138: 0.1171875
# Jaccard similarity between 1 and 1379: 0.0546875
# Jaccard similarity between 1 and 34147: 0.078125
# Jaccard similarity between 1 and 34149: 0.0859375
# Jaccard similarity between 1 and 34153: 0.0625
# Jaccard similarity between 1 and 1386: 0.09375
# Jaccard similarity between 1 and 1394: 0.0390625
# Jaccard similarity between 1 and 1402: 0.0546875
# Jaccard similarity between 1 and 34170: 0.125
# Jaccard similarity between 1 and 34172: 0.109375
# Jaccard similarity between 1 and 1414: 0.0625
# Jaccard similarity between 1 and 34198: 0.09375
# Jaccard similarity between 1 and 1433: 0.0859375
# Jaccard similarity between 1 and 1434: 0.09375
# Jaccard similarity between 1 and 34206: 0.1796875
# Jaccard similarity between 1 and 34215: 0.0546875
# Jaccard similarity between 1 and 1450: 0.1171875
# Jaccard similarity between 1 and 34223: 0.0703125
# Jaccard similarity between 1 and 1458: 0.0703125
# Jaccard similarity between 1 and 34227: 0.078125
# Jaccard similarity between 1 and 34239: 0.0625
# Jaccard similarity between 1 and 34240: 0.03125
# Jaccard similarity between 1 and 1473: 0.1328125
# Jaccard similarity between 1 and 34243: 0.0859375
# Jaccard similarity between 1 and 1476: 0.046875
# Jaccard similarity between 1 and 34244: 0.0859375
# Jaccard similarity between 1 and 34246: 0.0390625
# Jaccard similarity between 1 and 1477: 0.0390625
# Jaccard similarity between 1 and 34245: 0.09375
# Jaccard similarity between 1 and 34250: 0.0625
# Jaccard similarity between 1 and 34256: 0.078125
# Jaccard similarity between 1 and 34261: 0.09375
# Jaccard similarity between 1 and 34262: 0.0625
# Jaccard similarity between 1 and 1496: 0.078125
# Jaccard similarity between 1 and 34272: 0.078125
# Jaccard similarity between 1 and 1505: 0.0625
# Jaccard similarity between 1 and 34285: 0.0703125
# Jaccard similarity between 1 and 34301: 0.078125
# Jaccard similarity between 1 and 1534: 0.0859375
# Jaccard similarity between 1 and 34303: 0.078125
# Jaccard similarity between 1 and 34312: 0.078125
# Jaccard similarity between 1 and 34314: 0.078125
# Jaccard similarity between 1 and 34319: 0.0859375
# Jaccard similarity between 1 and 34322: 0.140625
# Jaccard similarity between 1 and 34335: 0.0546875
# Jaccard similarity between 1 and 1575: 0.078125
# Jaccard similarity between 1 and 34343: 0.046875
# Jaccard similarity between 1 and 1590: 0.0546875
# Jaccard similarity between 1 and 1592: 0.078125
# Jaccard similarity between 1 and 1600: 0.109375
# Jaccard similarity between 1 and 34370: 0.140625
# Jaccard similarity between 1 and 34372: 0.0625
# Jaccard similarity between 1 and 1608: 0.0390625
# Jaccard similarity between 1 and 34381: 0.0546875
# Jaccard similarity between 1 and 1619: 0.09375
# Jaccard similarity between 1 and 1627: 0.0859375
# Jaccard similarity between 1 and 34396: 0.0703125
# Jaccard similarity between 1 and 1631: 0.09375
# Jaccard similarity between 1 and 34401: 0.125
# Jaccard similarity between 1 and 1637: 0.078125
# Jaccard similarity between 1 and 1641: 0.0859375
# Jaccard similarity between 1 and 1647: 0.078125
# Jaccard similarity between 1 and 1649: 0.078125
# Jaccard similarity between 1 and 34429: 0.09375
# Jaccard similarity between 1 and 1663: 0.109375
# Jaccard similarity between 1 and 34431: 0.109375
# Jaccard similarity between 1 and 1665: 0.125
# Jaccard similarity between 1 and 34435: 0.0859375
# Jaccard similarity between 1 and 1668: 0.078125
# Jaccard similarity between 1 and 34438: 0.0546875
# Jaccard similarity between 1 and 1671: 0.03125
# Jaccard similarity between 1 and 34439: 0.109375
# Jaccard similarity between 1 and 1677: 0.1875
# Jaccard similarity between 1 and 34449: 0.0703125
# Jaccard similarity between 1 and 34453: 0.2421875
# Jaccard similarity between 1 and 34456: 0.0390625
# Jaccard similarity between 1 and 34457: 0.046875
# Jaccard similarity between 1 and 34466: 0.1015625
# Jaccard similarity between 1 and 34470: 0.1171875
# Jaccard similarity between 1 and 34472: 0.0703125
# Jaccard similarity between 1 and 1709: 0.1171875
# Jaccard similarity between 1 and 1715: 0.0546875
# Jaccard similarity between 1 and 1717: 0.109375
# Jaccard similarity between 1 and 34486: 0.109375
# Jaccard similarity between 1 and 1720: 0.078125
# Jaccard similarity between 1 and 34496: 0.1015625
# Jaccard similarity between 1 and 1729: 0.0703125
# Jaccard similarity between 1 and 34504: 0.125
# Jaccard similarity between 1 and 34511: 0.1328125
# Jaccard similarity between 1 and 34516: 0.0625
# Jaccard similarity between 1 and 1753: 0.109375
# Jaccard similarity between 1 and 1757: 0.09375
# Jaccard similarity between 1 and 1764: 0.0859375
# Jaccard similarity between 1 and 34533: 0.0859375
# Jaccard similarity between 1 and 1770: 0.078125
# Jaccard similarity between 1 and 34543: 0.0390625
# Jaccard similarity between 1 and 1779: 0.109375
# Jaccard similarity between 1 and 1784: 0.0625
# Jaccard similarity between 1 and 34561: 0.0859375
# Jaccard similarity between 1 and 1796: 0.0703125
# Jaccard similarity between 1 and 34565: 0.1015625
# Jaccard similarity between 1 and 34569: 0.0703125
# Jaccard similarity between 1 and 34572: 0.1015625
# Jaccard similarity between 1 and 34575: 0.0546875
# Jaccard similarity between 1 and 1809: 0.125
# Jaccard similarity between 1 and 1810: 0.109375
# Jaccard similarity between 1 and 1816: 0.1015625
# Jaccard similarity between 1 and 1818: 0.046875
# Jaccard similarity between 1 and 34591: 0.0625
# Jaccard similarity between 1 and 1824: 0.0390625
# Jaccard similarity between 1 and 1827: 0.1171875
# Jaccard similarity between 1 and 34595: 0.1015625
# Jaccard similarity between 1 and 1830: 0.09375
# Jaccard similarity between 1 and 34604: 0.0859375
# Jaccard similarity between 1 and 34607: 0.0625
# Jaccard similarity between 1 and 34614: 0.078125
# Jaccard similarity between 1 and 1854: 0.078125
# Jaccard similarity between 1 and 34627: 0.09375
# Jaccard similarity between 1 and 1860: 0.0546875
# Jaccard similarity between 1 and 1871: 0.09375
# Jaccard similarity between 1 and 34642: 0.125
# Jaccard similarity between 1 and 34644: 0.1328125
# Jaccard similarity between 1 and 34645: 0.078125
# Jaccard similarity between 1 and 1883: 0.0703125
# Jaccard similarity between 1 and 34652: 0.0703125
# Jaccard similarity between 1 and 1890: 0.1484375
# Jaccard similarity between 1 and 1897: 0.0625
# Jaccard similarity between 1 and 34666: 0.078125
# Jaccard similarity between 1 and 34672: 0.0859375
# Jaccard similarity between 1 and 34680: 0.0546875
# Jaccard similarity between 1 and 1913: 0.078125
# Jaccard similarity between 1 and 1914: 0.0859375
# Jaccard similarity between 1 and 1923: 0.1328125
# Jaccard similarity between 1 and 34696: 0.0546875
# Jaccard similarity between 1 and 1933: 0.1171875
# Jaccard similarity between 1 and 34703: 0.0859375
# Jaccard similarity between 1 and 34706: 0.1171875
# Jaccard similarity between 1 and 1942: 0.046875
# Jaccard similarity between 1 and 1944: 0.0703125
# Jaccard similarity between 1 and 1949: 0.1484375
# Jaccard similarity between 1 and 34723: 0.125
# Jaccard similarity between 1 and 34724: 0.0859375
# Jaccard similarity between 1 and 34729: 0.109375
# Jaccard similarity between 1 and 34737: 0.09375
# Jaccard similarity between 1 and 34744: 0.09375
# Jaccard similarity between 1 and 1977: 0.046875
# Jaccard similarity between 1 and 1984: 0.0625
# Jaccard similarity between 1 and 2020: 0.078125
# Jaccard similarity between 1 and 34790: 0.03125
# Jaccard similarity between 1 and 2023: 0.0546875
# Jaccard similarity between 1 and 2024: 0.0625
# Jaccard similarity between 1 and 34794: 0.046875
# Jaccard similarity between 1 and 34807: 0.1015625
# Jaccard similarity between 1 and 2055: 0.046875
# Jaccard similarity between 1 and 2060: 0.1171875
# Jaccard similarity between 1 and 34830: 0.0390625
# Jaccard similarity between 1 and 34831: 0.046875
# Jaccard similarity between 1 and 34840: 0.1484375
# Jaccard similarity between 1 and 34845: 0.09375
# Jaccard similarity between 1 and 2083: 0.0703125
# Jaccard similarity between 1 and 2085: 0.078125
# Jaccard similarity between 1 and 2089: 0.0546875
# Jaccard similarity between 1 and 2097: 0.0859375
# Jaccard similarity between 1 and 2104: 0.109375
# Jaccard similarity between 1 and 34878: 0.1328125
# Jaccard similarity between 1 and 2111: 0.0625
# Jaccard similarity between 1 and 34882: 0.09375
# Jaccard similarity between 1 and 34884: 0.0859375
# Jaccard similarity between 1 and 34887: 0.0703125
# Jaccard similarity between 1 and 34891: 0.078125
# Jaccard similarity between 1 and 2127: 0.0234375
# Jaccard similarity between 1 and 2132: 0.0546875
# Jaccard similarity between 1 and 34911: 0.046875
# Jaccard similarity between 1 and 2145: 0.078125
# Jaccard similarity between 1 and 34913: 0.0859375
# Jaccard similarity between 1 and 2160: 0.09375
# Jaccard similarity between 1 and 2161: 0.1015625
# Jaccard similarity between 1 and 2174: 0.1328125
# Jaccard similarity between 1 and 34944: 0.109375
# Jaccard similarity between 1 and 34952: 0.0703125
# Jaccard similarity between 1 and 34955: 0.078125
# Jaccard similarity between 1 and 34960: 0.0625
# Jaccard similarity between 1 and 34963: 0.1015625
# Jaccard similarity between 1 and 2201: 0.09375
# Jaccard similarity between 1 and 34969: 0.0625
# Jaccard similarity between 1 and 2204: 0.0859375
# Jaccard similarity between 1 and 34985: 0.0703125
# Jaccard similarity between 1 and 2221: 0.1015625
# Jaccard similarity between 1 and 2225: 0.0703125
# Jaccard similarity between 1 and 34993: 0.109375
# Jaccard similarity between 1 and 2250: 0.1015625
# Jaccard similarity between 1 and 35022: 0.0234375
# Jaccard similarity between 1 and 35024: 0.1328125
# Jaccard similarity between 1 and 35032: 0.0859375
# Jaccard similarity between 1 and 35038: 0.0859375
# Jaccard similarity between 1 and 35042: 0.1328125
# Jaccard similarity between 1 and 35046: 0.109375
# Jaccard similarity between 1 and 2279: 0.0546875
# Jaccard similarity between 1 and 35050: 0.078125
# Jaccard similarity between 1 and 2284: 0.109375
# Jaccard similarity between 1 and 2288: 0.1171875
# Jaccard similarity between 1 and 35061: 0.0859375
# Jaccard similarity between 1 and 35064: 0.1015625
# Jaccard similarity between 1 and 35067: 0.1171875
# Jaccard similarity between 1 and 2308: 0.1171875
# Jaccard similarity between 1 and 35088: 0.078125
# Jaccard similarity between 1 and 2330: 0.0703125
# Jaccard similarity between 1 and 2332: 0.09375
# Jaccard similarity between 1 and 2340: 0.0703125
# Jaccard similarity between 1 and 2350: 0.0625
# Jaccard similarity between 1 and 35120: 0.140625
# Jaccard similarity between 1 and 2355: 0.109375
# Jaccard similarity between 1 and 35124: 0.0546875
# Jaccard similarity between 1 and 35125: 0.0625
# Jaccard similarity between 1 and 35130: 0.109375
# Jaccard similarity between 1 and 35140: 0.078125
# Jaccard similarity between 1 and 35141: 0.046875
# Jaccard similarity between 1 and 2374: 0.1015625
# Jaccard similarity between 1 and 2376: 0.0625
# Jaccard similarity between 1 and 2382: 0.046875
# Jaccard similarity between 1 and 35155: 0.0390625
# Jaccard similarity between 1 and 2388: 0.109375
# Jaccard similarity between 1 and 2389: 0.09375
# Jaccard similarity between 1 and 35156: 0.1015625
# Jaccard similarity between 1 and 35161: 0.078125
# Jaccard similarity between 1 and 2395: 0.0859375
# Jaccard similarity between 1 and 2397: 0.03125
# Jaccard similarity between 1 and 2402: 0.1015625
# Jaccard similarity between 1 and 35180: 0.0859375
# Jaccard similarity between 1 and 35181: 0.109375
# Jaccard similarity between 1 and 35183: 0.078125
# Jaccard similarity between 1 and 35193: 0.09375
# Jaccard similarity between 1 and 2439: 0.0546875
# Jaccard similarity between 1 and 35208: 0.1328125
# Jaccard similarity between 1 and 35214: 0.140625
# Jaccard similarity between 1 and 2451: 0.0859375
# Jaccard similarity between 1 and 35221: 0.0546875
# Jaccard similarity between 1 and 2456: 0.078125
# Jaccard similarity between 1 and 35225: 0.125
# Jaccard similarity between 1 and 35227: 0.0625
# Jaccard similarity between 1 and 2459: 0.046875
# Jaccard similarity between 1 and 35232: 0.0703125
# Jaccard similarity between 1 and 2466: 0.0546875
# Jaccard similarity between 1 and 2469: 0.140625
# Jaccard similarity between 1 and 2472: 0.046875
# Jaccard similarity between 1 and 35242: 0.0703125
# Jaccard similarity between 1 and 35243: 0.03125
# Jaccard similarity between 1 and 2481: 0.078125
# Jaccard similarity between 1 and 35253: 0.1015625
# Jaccard similarity between 1 and 35255: 0.0234375
# Jaccard similarity between 1 and 2490: 0.1328125
# Jaccard similarity between 1 and 2491: 0.0390625
# Jaccard similarity between 1 and 2496: 0.0859375
# Jaccard similarity between 1 and 2504: 0.0625
# Jaccard similarity between 1 and 35274: 0.0859375
# Jaccard similarity between 1 and 35276: 0.15625
# Jaccard similarity between 1 and 35277: 0.0390625
# Jaccard similarity between 1 and 2516: 0.0625
# Jaccard similarity between 1 and 35285: 0.0546875
# Jaccard similarity between 1 and 35286: 0.0390625
# Jaccard similarity between 1 and 35290: 0.0703125
# Jaccard similarity between 1 and 35307: 0.1171875
# Jaccard similarity between 1 and 2541: 0.078125
# Jaccard similarity between 1 and 2546: 0.0859375
# Jaccard similarity between 1 and 35315: 0.0703125
# Jaccard similarity between 1 and 2559: 0.0390625
# Jaccard similarity between 1 and 35338: 0.0859375
# Jaccard similarity between 1 and 35346: 0.09375
# Jaccard similarity between 1 and 2596: 0.09375
# Jaccard similarity between 1 and 35364: 0.0546875
# Jaccard similarity between 1 and 35368: 0.0859375
# Jaccard similarity between 1 and 2601: 0.046875
# Jaccard similarity between 1 and 35380: 0.0546875
# Jaccard similarity between 1 and 2615: 0.109375
# Jaccard similarity between 1 and 35384: 0.1015625
# Jaccard similarity between 1 and 2619: 0.0390625
# Jaccard similarity between 1 and 2634: 0.09375
# Jaccard similarity between 1 and 2635: 0.0703125
# Jaccard similarity between 1 and 35403: 0.125
# Jaccard similarity between 1 and 2638: 0.0859375
# Jaccard similarity between 1 and 35412: 0.046875
# Jaccard similarity between 1 and 35413: 0.09375
# Jaccard similarity between 1 and 2651: 0.0859375
# Jaccard similarity between 1 and 2654: 0.0703125
# Jaccard similarity between 1 and 35425: 0.0625
# Jaccard similarity between 1 and 2669: 0.109375
# Jaccard similarity between 1 and 2678: 0.0859375
# Jaccard similarity between 1 and 2679: 0.0546875
# Jaccard similarity between 1 and 2684: 0.1015625
# Jaccard similarity between 1 and 35458: 0.1328125
# Jaccard similarity between 1 and 2691: 0.109375
# Jaccard similarity between 1 and 2694: 0.078125
# Jaccard similarity between 1 and 2698: 0.03125
# Jaccard similarity between 1 and 2700: 0.046875
# Jaccard similarity between 1 and 35469: 0.109375
# Jaccard similarity between 1 and 35473: 0.0703125
# Jaccard similarity between 1 and 35488: 0.1015625
# Jaccard similarity between 1 and 35489: 0.0859375
# Jaccard similarity between 1 and 2722: 0.1171875
# Jaccard similarity between 1 and 2726: 0.09375
# Jaccard similarity between 1 and 35495: 0.0390625
# Jaccard similarity between 1 and 35500: 0.078125
# Jaccard similarity between 1 and 35501: 0.109375
# Jaccard similarity between 1 and 35503: 0.0390625
# Jaccard similarity between 1 and 2747: 0.0625
# Jaccard similarity between 1 and 2749: 0.109375
# Jaccard similarity between 1 and 35522: 0.078125
# Jaccard similarity between 1 and 35524: 0.09375
# Jaccard similarity between 1 and 35526: 0.0703125
# Jaccard similarity between 1 and 35535: 0.0625
# Jaccard similarity between 1 and 2769: 0.09375
# Jaccard similarity between 1 and 35538: 0.0859375
# Jaccard similarity between 1 and 2771: 0.078125
# Jaccard similarity between 1 and 2781: 0.0546875
# Jaccard similarity between 1 and 2783: 0.0859375
# Jaccard similarity between 1 and 2787: 0.1015625
# Jaccard similarity between 1 and 2791: 0.078125
# Jaccard similarity between 1 and 2792: 0.109375
# Jaccard similarity between 1 and 35561: 0.078125
# Jaccard similarity between 1 and 2793: 0.109375
# Jaccard similarity between 1 and 2799: 0.09375
# Jaccard similarity between 1 and 2800: 0.0703125
# Jaccard similarity between 1 and 2815: 0.0625
# Jaccard similarity between 1 and 35586: 0.078125
# Jaccard similarity between 1 and 2821: 0.0703125
# Jaccard similarity between 1 and 2831: 0.09375
# Jaccard similarity between 1 and 35599: 0.078125
# Jaccard similarity between 1 and 2839: 0.0625
# Jaccard similarity between 1 and 35607: 0.0625
# Jaccard similarity between 1 and 35609: 0.140625
# Jaccard similarity between 1 and 35614: 0.078125
# Jaccard similarity between 1 and 2855: 0.0859375
# Jaccard similarity between 1 and 2860: 0.0859375
# Jaccard similarity between 1 and 35629: 0.0859375
# Jaccard similarity between 1 and 35630: 0.0703125
# Jaccard similarity between 1 and 2864: 0.078125
# Jaccard similarity between 1 and 2865: 0.0625
# Jaccard similarity between 1 and 35634: 0.03125
# Jaccard similarity between 1 and 2866: 0.0546875
# Jaccard similarity between 1 and 35652: 0.046875
# Jaccard similarity between 1 and 35667: 0.0546875
# Jaccard similarity between 1 and 2902: 0.09375
# Jaccard similarity between 1 and 2907: 0.1015625
# Jaccard similarity between 1 and 35682: 0.0703125
# Jaccard similarity between 1 and 35685: 0.0703125
# Jaccard similarity between 1 and 2920: 0.0859375
# Jaccard similarity between 1 and 35696: 0.0390625
# Jaccard similarity between 1 and 2932: 0.0390625
# Jaccard similarity between 1 and 35701: 0.078125
# Jaccard similarity between 1 and 35702: 0.109375
# Jaccard similarity between 1 and 2942: 0.078125
# Jaccard similarity between 1 and 2944: 0.109375
# Jaccard similarity between 1 and 35718: 0.109375
# Jaccard similarity between 1 and 2956: 0.109375
# Jaccard similarity between 1 and 35725: 0.1171875
# Jaccard similarity between 1 and 35727: 0.1015625
# Jaccard similarity between 1 and 35729: 0.046875
# Jaccard similarity between 1 and 35733: 0.15625
# Jaccard similarity between 1 and 2968: 0.03125
# Jaccard similarity between 1 and 2969: 0.0859375
# Jaccard similarity between 1 and 35738: 0.09375
# Jaccard similarity between 1 and 2971: 0.09375
# Jaccard similarity between 1 and 2972: 0.0625
# Jaccard similarity between 1 and 2973: 0.078125
# Jaccard similarity between 1 and 2981: 0.0546875
# Jaccard similarity between 1 and 35749: 0.0703125
# Jaccard similarity between 1 and 2991: 0.109375
# Jaccard similarity between 1 and 2994: 0.046875
# Jaccard similarity between 1 and 35764: 0.1015625
# Jaccard similarity between 1 and 3006: 0.0703125
# Jaccard similarity between 1 and 3009: 0.125
# Jaccard similarity between 1 and 35781: 0.0859375
# Jaccard similarity between 1 and 3019: 0.0546875
# Jaccard similarity between 1 and 35788: 0.0546875
# Jaccard similarity between 1 and 3025: 0.046875
# Jaccard similarity between 1 and 35794: 0.078125
# Jaccard similarity between 1 and 3032: 0.1015625
# Jaccard similarity between 1 and 35803: 0.09375
# Jaccard similarity between 1 and 3042: 0.1015625
# Jaccard similarity between 1 and 3047: 0.0703125
# Jaccard similarity between 1 and 3049: 0.1015625
# Jaccard similarity between 1 and 35821: 0.0859375
# Jaccard similarity between 1 and 3053: 0.0859375
# Jaccard similarity between 1 and 35824: 0.0625
# Jaccard similarity between 1 and 3057: 0.1015625
# Jaccard similarity between 1 and 3061: 0.0546875
# Jaccard similarity between 1 and 3063: 0.046875
# Jaccard similarity between 1 and 35834: 0.09375
# Jaccard similarity between 1 and 35835: 0.09375
# Jaccard similarity between 1 and 3068: 0.078125
# Jaccard similarity between 1 and 35838: 0.1015625
# Jaccard similarity between 1 and 35842: 0.078125
# Jaccard similarity between 1 and 3080: 0.046875
# Jaccard similarity between 1 and 35850: 0.109375
# Jaccard similarity between 1 and 3090: 0.046875
# Jaccard similarity between 1 and 3097: 0.0859375
# Jaccard similarity between 1 and 3100: 0.0546875
# Jaccard similarity between 1 and 35872: 0.0703125
# Jaccard similarity between 1 and 35890: 0.0390625
# Jaccard similarity between 1 and 3135: 0.0703125
# Jaccard similarity between 1 and 35909: 0.0703125
# Jaccard similarity between 1 and 35916: 0.0859375
# Jaccard similarity between 1 and 3149: 0.0703125
# Jaccard similarity between 1 and 35921: 0.1015625
# Jaccard similarity between 1 and 35928: 0.09375
# Jaccard similarity between 1 and 35929: 0.109375
# Jaccard similarity between 1 and 35931: 0.0625
# Jaccard similarity between 1 and 3164: 0.0390625
# Jaccard similarity between 1 and 3166: 0.0703125
# Jaccard similarity between 1 and 3171: 0.1015625
# Jaccard similarity between 1 and 3175: 0.0859375
# Jaccard similarity between 1 and 3178: 0.078125
# Jaccard similarity between 1 and 35948: 0.078125
# Jaccard similarity between 1 and 35949: 0.125
# Jaccard similarity between 1 and 35950: 0.0625
# Jaccard similarity between 1 and 35952: 0.0546875
# Jaccard similarity between 1 and 3185: 0.0703125
# Jaccard similarity between 1 and 3186: 0.109375
# Jaccard similarity between 1 and 35955: 0.1328125
# Jaccard similarity between 1 and 35956: 0.0546875
# Jaccard similarity between 1 and 35961: 0.0859375
# Jaccard similarity between 1 and 3196: 0.1015625
# Jaccard similarity between 1 and 3199: 0.1015625
# Jaccard similarity between 1 and 3206: 0.1171875
# Jaccard similarity between 1 and 3210: 0.0859375
# Jaccard similarity between 1 and 3211: 0.0625
# Jaccard similarity between 1 and 3228: 0.0859375
# Jaccard similarity between 1 and 35998: 0.0625
# Jaccard similarity between 1 and 3234: 0.0859375
# Jaccard similarity between 1 and 3236: 0.0859375
# Jaccard similarity between 1 and 3237: 0.109375
# Jaccard similarity between 1 and 3246: 0.0703125
# Jaccard similarity between 1 and 36018: 0.0859375
# Jaccard similarity between 1 and 36025: 0.078125
# Jaccard similarity between 1 and 3263: 0.0703125
# Jaccard similarity between 1 and 36039: 0.1328125
# Jaccard similarity between 1 and 3272: 0.1171875
# Jaccard similarity between 1 and 36043: 0.0625
# Jaccard similarity between 1 and 3279: 0.0859375
# Jaccard similarity between 1 and 3286: 0.109375
# Jaccard similarity between 1 and 3296: 0.1015625
# Jaccard similarity between 1 and 3303: 0.09375
# Jaccard similarity between 1 and 36077: 0.0546875
# Jaccard similarity between 1 and 3319: 0.078125
# Jaccard similarity between 1 and 36089: 0.078125
# Jaccard similarity between 1 and 36092: 0.0703125
# Jaccard similarity between 1 and 36093: 0.109375
# Jaccard similarity between 1 and 36097: 0.0625
# Jaccard similarity between 1 and 3330: 0.109375
# Jaccard similarity between 1 and 3329: 0.078125
# Jaccard similarity between 1 and 36101: 0.078125
# Jaccard similarity between 1 and 36110: 0.0859375
# Jaccard similarity between 1 and 36113: 0.109375
# Jaccard similarity between 1 and 3353: 0.03125
# Jaccard similarity between 1 and 36126: 0.0703125
# Jaccard similarity between 1 and 36133: 0.0625
# Jaccard similarity between 1 and 3372: 0.09375
# Jaccard similarity between 1 and 36140: 0.1171875
# Jaccard similarity between 1 and 36142: 0.0859375
# Jaccard similarity between 1 and 36158: 0.0546875
# Jaccard similarity between 1 and 36160: 0.109375
# Jaccard similarity between 1 and 36162: 0.078125
# Jaccard similarity between 1 and 36170: 0.0859375
# Jaccard similarity between 1 and 36172: 0.09375
# Jaccard similarity between 1 and 3406: 0.078125
# Jaccard similarity between 1 and 3408: 0.0546875
# Jaccard similarity between 1 and 36185: 0.1015625
# Jaccard similarity between 1 and 36189: 0.0546875
# Jaccard similarity between 1 and 36194: 0.078125
# Jaccard similarity between 1 and 36198: 0.0625
# Jaccard similarity between 1 and 3431: 0.1171875
# Jaccard similarity between 1 and 36211: 0.1015625
# Jaccard similarity between 1 and 36213: 0.046875
# Jaccard similarity between 1 and 36219: 0.0859375
# Jaccard similarity between 1 and 36233: 0.0859375
# Jaccard similarity between 1 and 3466: 0.0625
# Jaccard similarity between 1 and 3467: 0.0703125
# Jaccard similarity between 1 and 3489: 0.125
# Jaccard similarity between 1 and 3490: 0.0859375
# Jaccard similarity between 1 and 36258: 0.0703125
# Jaccard similarity between 1 and 36260: 0.078125
# Jaccard similarity between 1 and 3494: 0.046875
# Jaccard similarity between 1 and 36263: 0.0625
# Jaccard similarity between 1 and 3496: 0.0703125
# Jaccard similarity between 1 and 36268: 0.078125
# Jaccard similarity between 1 and 36272: 0.0859375
# Jaccard similarity between 1 and 3508: 0.1640625
# Jaccard similarity between 1 and 3527: 0.1171875
# Jaccard similarity between 1 and 3528: 0.1171875
# Jaccard similarity between 1 and 3531: 0.0546875
# Jaccard similarity between 1 and 36307: 0.0625
# Jaccard similarity between 1 and 3548: 0.0546875
# Jaccard similarity between 1 and 3550: 0.0703125
# Jaccard similarity between 1 and 3566: 0.0859375
# Jaccard similarity between 1 and 3568: 0.1171875
# Jaccard similarity between 1 and 3574: 0.1171875
# Jaccard similarity between 1 and 36343: 0.09375
# Jaccard similarity between 1 and 36362: 0.1484375
# Jaccard similarity between 1 and 36375: 0.109375
# Jaccard similarity between 1 and 36378: 0.1015625
# Jaccard similarity between 1 and 36385: 0.0390625
# Jaccard similarity between 1 and 36396: 0.1015625
# Jaccard similarity between 1 and 3637: 0.0625
# Jaccard similarity between 1 and 3638: 0.09375
# Jaccard similarity between 1 and 3639: 0.0859375
# Jaccard similarity between 1 and 36409: 0.0625
# Jaccard similarity between 1 and 3643: 0.09375
# Jaccard similarity between 1 and 36422: 0.109375
# Jaccard similarity between 1 and 36423: 0.078125
# Jaccard similarity between 1 and 36425: 0.0234375
# Jaccard similarity between 1 and 36429: 0.109375
# Jaccard similarity between 1 and 36439: 0.0703125
# Jaccard similarity between 1 and 36443: 0.0546875
# Jaccard similarity between 1 and 3680: 0.0703125
# Jaccard similarity between 1 and 36449: 0.0703125
# Jaccard similarity between 1 and 3682: 0.0546875
# Jaccard similarity between 1 and 36450: 0.0859375
# Jaccard similarity between 1 and 36460: 0.078125
# Jaccard similarity between 1 and 36464: 0.0703125
# Jaccard similarity between 1 and 36465: 0.0546875
# Jaccard similarity between 1 and 36466: 0.046875
# Jaccard similarity between 1 and 3702: 0.0703125
# Jaccard similarity between 1 and 36471: 0.125
# Jaccard similarity between 1 and 36472: 0.1171875
# Jaccard similarity between 1 and 3712: 0.0703125
# Jaccard similarity between 1 and 3716: 0.0546875
# Jaccard similarity between 1 and 36484: 0.1015625
# Jaccard similarity between 1 and 36488: 0.09375
# Jaccard similarity between 1 and 3723: 0.078125
# Jaccard similarity between 1 and 3724: 0.03125
# Jaccard similarity between 1 and 3726: 0.0390625
# Jaccard similarity between 1 and 36499: 0.0546875
# Jaccard similarity between 1 and 3736: 0.0625
# Jaccard similarity between 1 and 36511: 0.0390625
# Jaccard similarity between 1 and 3750: 0.109375
# Jaccard similarity between 1 and 36520: 0.1015625
# Jaccard similarity between 1 and 3768: 0.0546875
# Jaccard similarity between 1 and 3769: 0.0703125
# Jaccard similarity between 1 and 36542: 0.140625
# Jaccard similarity between 1 and 36543: 0.0546875
# Jaccard similarity between 1 and 36550: 0.078125
# Jaccard similarity between 1 and 3789: 0.1171875
# Jaccard similarity between 1 and 3793: 0.09375
# Jaccard similarity between 1 and 3808: 0.125
# Jaccard similarity between 1 and 36584: 0.109375
# Jaccard similarity between 1 and 36590: 0.0625
# Jaccard similarity between 1 and 3828: 0.1015625
# Jaccard similarity between 1 and 3834: 0.078125
# Jaccard similarity between 1 and 3835: 0.09375
# Jaccard similarity between 1 and 36616: 0.125
# Jaccard similarity between 1 and 36624: 0.0625
# Jaccard similarity between 1 and 3856: 0.09375
# Jaccard similarity between 1 and 3860: 0.0859375
# Jaccard similarity between 1 and 3864: 0.0546875
# Jaccard similarity between 1 and 3866: 0.1171875
# Jaccard similarity between 1 and 3869: 0.0859375
# Jaccard similarity between 1 and 3879: 0.1171875
# Jaccard similarity between 1 and 36649: 0.0859375
# Jaccard similarity between 1 and 36654: 0.09375
# Jaccard similarity between 1 and 36657: 0.0859375
# Jaccard similarity between 1 and 3898: 0.0703125
# Jaccard similarity between 1 and 36679: 0.1015625
# Jaccard similarity between 1 and 36681: 0.09375
# Jaccard similarity between 1 and 3916: 0.0859375
# Jaccard similarity between 1 and 36687: 0.0625
# Jaccard similarity between 1 and 3920: 0.0859375
# Jaccard similarity between 1 and 3923: 0.078125
# Jaccard similarity between 1 and 3926: 0.0546875
# Jaccard similarity between 1 and 3933: 0.078125
# Jaccard similarity between 1 and 36701: 0.1171875
# Jaccard similarity between 1 and 36707: 0.1484375
# Jaccard similarity between 1 and 3943: 0.078125
# Jaccard similarity between 1 and 36711: 0.0859375
# Jaccard similarity between 1 and 3949: 0.09375
# Jaccard similarity between 1 and 3951: 0.0546875
# Jaccard similarity between 1 and 36730: 0.046875
# Jaccard similarity between 1 and 3963: 0.0703125
# Jaccard similarity between 1 and 36744: 0.0859375
# Jaccard similarity between 1 and 3986: 0.109375
# Jaccard similarity between 1 and 3989: 0.0703125
# Jaccard similarity between 1 and 36778: 0.109375
# Jaccard similarity between 1 and 4021: 0.046875
# Jaccard similarity between 1 and 4022: 0.0703125
# Jaccard similarity between 1 and 4028: 0.1171875
# Jaccard similarity between 1 and 36798: 0.09375
# Jaccard similarity between 1 and 36804: 0.0625
# Jaccard similarity between 1 and 4037: 0.0703125
# Jaccard similarity between 1 and 4045: 0.125
# Jaccard similarity between 1 and 4055: 0.0625
# Jaccard similarity between 1 and 36838: 0.078125
# Jaccard similarity between 1 and 36841: 0.1015625
# Jaccard similarity between 1 and 36844: 0.09375
# Jaccard similarity between 1 and 36845: 0.1015625
# Jaccard similarity between 1 and 36848: 0.0625
# Jaccard similarity between 1 and 4087: 0.1171875
# Jaccard similarity between 1 and 4088: 0.0546875
# Jaccard similarity between 1 and 36857: 0.109375
# Jaccard similarity between 1 and 36855: 0.1640625
# Jaccard similarity between 1 and 36859: 0.1015625
# Jaccard similarity between 1 and 36864: 0.0703125
# Jaccard similarity between 1 and 36869: 0.109375
# Jaccard similarity between 1 and 36880: 0.03125
# Jaccard similarity between 1 and 36890: 0.078125
# Jaccard similarity between 1 and 4126: 0.078125
# Jaccard similarity between 1 and 4131: 0.0625
# Jaccard similarity between 1 and 36915: 0.140625
# Jaccard similarity between 1 and 4155: 0.0546875
# Jaccard similarity between 1 and 36929: 0.109375
# Jaccard similarity between 1 and 36933: 0.078125
# Jaccard similarity between 1 and 4166: 0.0390625
# Jaccard similarity between 1 and 36934: 0.0234375
# Jaccard similarity between 1 and 4169: 0.09375
# Jaccard similarity between 1 and 36938: 0.109375
# Jaccard similarity between 1 and 4172: 0.0546875
# Jaccard similarity between 1 and 36940: 0.1015625
# Jaccard similarity between 1 and 36944: 0.0625
# Jaccard similarity between 1 and 36951: 0.1015625
# Jaccard similarity between 1 and 36953: 0.1015625
# Jaccard similarity between 1 and 4189: 0.1015625
# Jaccard similarity between 1 and 36959: 0.0625
# Jaccard similarity between 1 and 36960: 0.0703125
# Jaccard similarity between 1 and 4193: 0.0390625
# Jaccard similarity between 1 and 36967: 0.078125
# Jaccard similarity between 1 and 4208: 0.0703125
# Jaccard similarity between 1 and 4210: 0.09375
# Jaccard similarity between 1 and 4211: 0.1171875
# Jaccard similarity between 1 and 36980: 0.1015625
# Jaccard similarity between 1 and 36981: 0.0546875
# Jaccard similarity between 1 and 4216: 0.0546875
# Jaccard similarity between 1 and 36987: 0.09375
# Jaccard similarity between 1 and 4221: 0.078125
# Jaccard similarity between 1 and 36990: 0.078125
# Jaccard similarity between 1 and 4227: 0.0703125
# Jaccard similarity between 1 and 37004: 0.09375
# Jaccard similarity between 1 and 4237: 0.078125
# Jaccard similarity between 1 and 37005: 0.046875
# Jaccard similarity between 1 and 4247: 0.0234375
# Jaccard similarity between 1 and 4255: 0.09375
# Jaccard similarity between 1 and 4257: 0.140625
# Jaccard similarity between 1 and 4265: 0.171875
# Jaccard similarity between 1 and 4267: 0.046875
# Jaccard similarity between 1 and 4289: 0.078125
# Jaccard similarity between 1 and 37061: 0.1328125
# Jaccard similarity between 1 and 4297: 0.046875
# Jaccard similarity between 1 and 37066: 0.0625
# Jaccard similarity between 1 and 37082: 0.0703125
# Jaccard similarity between 1 and 4325: 0.1015625
# Jaccard similarity between 1 and 37100: 0.0703125
# Jaccard similarity between 1 and 37109: 0.0546875
# Jaccard similarity between 1 and 37110: 0.15625
# Jaccard similarity between 1 and 4342: 0.0625
# Jaccard similarity between 1 and 4351: 0.125
# Jaccard similarity between 1 and 4353: 0.09375
# Jaccard similarity between 1 and 4354: 0.0859375
# Jaccard similarity between 1 and 37129: 0.1171875
# Jaccard similarity between 1 and 4366: 0.0703125
# Jaccard similarity between 1 and 4372: 0.1015625
# Jaccard similarity between 1 and 37146: 0.0546875
# Jaccard similarity between 1 and 4379: 0.0703125
# Jaccard similarity between 1 and 37151: 0.0390625
# Jaccard similarity between 1 and 4389: 0.09375
# Jaccard similarity between 1 and 4395: 0.0703125
# Jaccard similarity between 1 and 4408: 0.0859375
# Jaccard similarity between 1 and 37178: 0.0703125
# Jaccard similarity between 1 and 37203: 0.0859375
# Jaccard similarity between 1 and 4436: 0.0546875
# Jaccard similarity between 1 and 4443: 0.0703125
# Jaccard similarity between 1 and 37218: 0.015625
# Jaccard similarity between 1 and 37224: 0.109375
# Jaccard similarity between 1 and 4461: 0.125
# Jaccard similarity between 1 and 4468: 0.09375
# Jaccard similarity between 1 and 37238: 0.1015625
# Jaccard similarity between 1 and 37241: 0.078125
# Jaccard similarity between 1 and 37242: 0.140625
# Jaccard similarity between 1 and 4481: 0.046875
# Jaccard similarity between 1 and 4485: 0.1328125
# Jaccard similarity between 1 and 4490: 0.078125
# Jaccard similarity between 1 and 37261: 0.1015625
# Jaccard similarity between 1 and 37266: 0.03125
# Jaccard similarity between 1 and 37272: 0.0703125
# ...
# Jaccard similarity between 1 and 29770: 0.1015625
# Jaccard similarity between 1 and 29776: 0.0390625
# Jaccard similarity between 1 and 29777: 0.09375
# Jaccard similarity between 1 and 29778: 0.1484375
# Jaccard similarity between 1 and 29795: 0.0859375
# Jaccard similarity between 1 and 29809: 0.109375
# Jaccard similarity between 1 and 29815: 0.078125
# Jaccard similarity between 1 and 29822: 0.140625
# Jaccard similarity between 1 and 29826: 0.0703125
# Jaccard similarity between 1 and 29832: 0.0703125
# Jaccard similarity between 1 and 29843: 0.09375
# Jaccard similarity between 1 and 29844: 0.09375
# Jaccard similarity between 1 and 29864: 0.078125
# Jaccard similarity between 1 and 29876: 0.078125
# Jaccard similarity between 1 and 29877: 0.046875
# Jaccard similarity between 1 and 29880: 0.140625
# Jaccard similarity between 1 and 29888: 0.0703125
# Jaccard similarity between 1 and 29893: 0.1171875
# Jaccard similarity between 1 and 29896: 0.109375
# Jaccard similarity between 1 and 29913: 0.078125
# Jaccard similarity between 1 and 29941: 0.046875
# Jaccard similarity between 1 and 29946: 0.0390625
# Jaccard similarity between 1 and 29948: 0.03125
# Jaccard similarity between 1 and 29967: 0.1171875
# Jaccard similarity between 1 and 29978: 0.0390625
# Jaccard similarity between 1 and 29983: 0.15625
# Jaccard similarity between 1 and 29985: 0.1015625
# Jaccard similarity between 1 and 29997: 0.03125
# Jaccard similarity between 1 and 30002: 0.1015625
# Jaccard similarity between 1 and 30005: 0.109375
# Jaccard similarity between 1 and 30013: 0.0859375
# Jaccard similarity between 1 and 30018: 0.046875
# Jaccard similarity between 1 and 30045: 0.0546875
# Jaccard similarity between 1 and 30054: 0.09375
# Jaccard similarity between 1 and 30063: 0.1015625
# Jaccard similarity between 1 and 30069: 0.0703125
# Jaccard similarity between 1 and 30071: 0.0625
# Jaccard similarity between 1 and 30076: 0.0859375
# Jaccard similarity between 1 and 30096: 0.046875
# Jaccard similarity between 1 and 30111: 0.1171875
# Jaccard similarity between 1 and 30128: 0.0625
# Jaccard similarity between 1 and 30141: 0.0859375
# Jaccard similarity between 1 and 30146: 0.109375
# Jaccard similarity between 1 and 30164: 0.0546875
# Jaccard similarity between 1 and 30175: 0.0859375
# Jaccard similarity between 1 and 30181: 0.109375
# Jaccard similarity between 1 and 30195: 0.109375
# Jaccard similarity between 1 and 30196: 0.09375
# Jaccard similarity between 1 and 30204: 0.140625
# Jaccard similarity between 1 and 30206: 0.0546875
# Jaccard similarity between 1 and 30208: 0.0625
# Jaccard similarity between 1 and 30218: 0.0625
# Jaccard similarity between 1 and 30219: 0.0390625
# Jaccard similarity between 1 and 30227: 0.0703125
# Jaccard similarity between 1 and 30240: 0.078125
# Jaccard similarity between 1 and 30245: 0.0546875
# Jaccard similarity between 1 and 30249: 0.0859375
# Jaccard similarity between 1 and 30275: 0.09375
# Jaccard similarity between 1 and 30289: 0.046875
# Jaccard similarity between 1 and 30293: 0.0546875
# Jaccard similarity between 1 and 30297: 0.0859375
# Jaccard similarity between 1 and 30316: 0.046875
# Jaccard similarity between 1 and 30317: 0.1015625
# Jaccard similarity between 1 and 30325: 0.078125
# Jaccard similarity between 1 and 30365: 0.0859375
# Jaccard similarity between 1 and 30370: 0.1015625
# Jaccard similarity between 1 and 30371: 0.0390625
# Jaccard similarity between 1 and 30375: 0.0703125
# Jaccard similarity between 1 and 30419: 0.0859375
# Jaccard similarity between 1 and 30434: 0.0625
# Jaccard similarity between 1 and 30457: 0.078125
# Jaccard similarity between 1 and 30458: 0.0703125
# Jaccard similarity between 1 and 30474: 0.0546875
# Jaccard similarity between 1 and 30483: 0.0703125
# Jaccard similarity between 1 and 30494: 0.109375
# Jaccard similarity between 1 and 30497: 0.046875
# Jaccard similarity between 1 and 30512: 0.0703125
# Jaccard similarity between 1 and 30517: 0.078125
# Jaccard similarity between 1 and 30520: 0.0546875
# Jaccard similarity between 1 and 30522: 0.03125
# Jaccard similarity between 1 and 30527: 0.0390625
# Jaccard similarity between 1 and 30531: 0.125
# Jaccard similarity between 1 and 30537: 0.0703125
# Jaccard similarity between 1 and 30542: 0.1015625
# Jaccard similarity between 1 and 30546: 0.0625
# Jaccard similarity between 1 and 30569: 0.0625
# Jaccard similarity between 1 and 30576: 0.046875
# Jaccard similarity between 1 and 30611: 0.0546875
# Jaccard similarity between 1 and 30617: 0.0546875
# Jaccard similarity between 1 and 30624: 0.078125
# Jaccard similarity between 1 and 30628: 0.109375
# Jaccard similarity between 1 and 30630: 0.0390625
# Jaccard similarity between 1 and 30639: 0.125
# Jaccard similarity between 1 and 30652: 0.0703125
# Jaccard similarity between 1 and 30658: 0.078125
# Jaccard similarity between 1 and 30676: 0.0625
# Jaccard similarity between 1 and 30677: 0.09375
# Jaccard similarity between 1 and 30678: 0.078125
# Jaccard similarity between 1 and 30684: 0.0859375
# Jaccard similarity between 1 and 30691: 0.078125
# Jaccard similarity between 1 and 30702: 0.0546875
# Jaccard similarity between 1 and 30704: 0.0546875
# Jaccard similarity between 1 and 30721: 0.0859375
# Jaccard similarity between 1 and 30735: 0.0859375
# Jaccard similarity between 1 and 30746: 0.1015625
# Jaccard similarity between 1 and 30749: 0.078125
# Jaccard similarity between 1 and 30762: 0.078125
# Jaccard similarity between 1 and 30763: 0.0625
# Jaccard similarity between 1 and 30776: 0.0703125
# Jaccard similarity between 1 and 30780: 0.109375
# Jaccard similarity between 1 and 30788: 0.0390625
# Jaccard similarity between 1 and 30795: 0.0859375
# Jaccard similarity between 1 and 30814: 0.1015625
# Jaccard similarity between 1 and 30824: 0.0703125
# Jaccard similarity between 1 and 30828: 0.0703125
# Jaccard similarity between 1 and 30835: 0.09375
# Jaccard similarity between 1 and 30843: 0.0234375
# Jaccard similarity between 1 and 30858: 0.1171875
# Jaccard similarity between 1 and 30863: 0.09375
# Jaccard similarity between 1 and 30873: 0.03125
# Jaccard similarity between 1 and 30879: 0.0859375
# Jaccard similarity between 1 and 30895: 0.140625
# Jaccard similarity between 1 and 30899: 0.1171875
# Jaccard similarity between 1 and 30904: 0.125
# Jaccard similarity between 1 and 30910: 0.1328125
# Jaccard similarity between 1 and 30919: 0.1015625
# Jaccard similarity between 1 and 30932: 0.0859375
# Jaccard similarity between 1 and 30933: 0.0859375
# Jaccard similarity between 1 and 30935: 0.0625
# Jaccard similarity between 1 and 30944: 0.0703125
# Jaccard similarity between 1 and 30962: 0.0703125
# Jaccard similarity between 1 and 30963: 0.09375
# Jaccard similarity between 1 and 30979: 0.1171875
# Jaccard similarity between 1 and 31007: 0.078125
# Jaccard similarity between 1 and 31018: 0.0859375
# Jaccard similarity between 1 and 31026: 0.09375
# Jaccard similarity between 1 and 31045: 0.0703125
# Jaccard similarity between 1 and 31050: 0.0859375
# Jaccard similarity between 1 and 31058: 0.0703125
# Jaccard similarity between 1 and 31069: 0.0390625
# Jaccard similarity between 1 and 31080: 0.0703125
# Jaccard similarity between 1 and 31084: 0.1328125
# Jaccard similarity between 1 and 31109: 0.078125
# Jaccard similarity between 1 and 31111: 0.0546875
# Jaccard similarity between 1 and 31125: 0.1328125
# Jaccard similarity between 1 and 31139: 0.0703125
# Jaccard similarity between 1 and 31140: 0.15625
# Jaccard similarity between 1 and 31144: 0.078125
# Jaccard similarity between 1 and 31145: 0.078125
# Jaccard similarity between 1 and 31160: 0.03125
# Jaccard similarity between 1 and 31164: 0.09375
# Jaccard similarity between 1 and 31168: 0.0546875
# Jaccard similarity between 1 and 31170: 0.078125
# Jaccard similarity between 1 and 31171: 0.0390625
# Jaccard similarity between 1 and 31172: 0.09375
# Jaccard similarity between 1 and 31186: 0.0703125
# Jaccard similarity between 1 and 31193: 0.125
# Jaccard similarity between 1 and 31194: 0.0625
# Jaccard similarity between 1 and 31203: 0.0859375
# Jaccard similarity between 1 and 31217: 0.140625
# Jaccard similarity between 1 and 31221: 0.0625
# Jaccard similarity between 1 and 31225: 0.0546875
# Jaccard similarity between 1 and 31227: 0.078125
# Jaccard similarity between 1 and 31230: 0.15625
# Jaccard similarity between 1 and 31242: 0.078125
# Jaccard similarity between 1 and 31259: 0.140625
# Jaccard similarity between 1 and 31264: 0.09375
# Jaccard similarity between 1 and 31274: 0.078125
# Jaccard similarity between 1 and 31276: 0.0546875
# Jaccard similarity between 1 and 31289: 0.0546875
# Jaccard similarity between 1 and 31297: 0.078125
# Jaccard similarity between 1 and 31304: 0.078125
# Jaccard similarity between 1 and 31308: 0.046875
# Jaccard similarity between 1 and 31334: 0.0703125
# Jaccard similarity between 1 and 31360: 0.0859375
# Jaccard similarity between 1 and 31364: 0.09375
# Jaccard similarity between 1 and 31367: 0.078125
# Jaccard similarity between 1 and 31382: 0.140625
# Jaccard similarity between 1 and 31389: 0.109375
# Jaccard similarity between 1 and 31392: 0.046875
# Jaccard similarity between 1 and 31398: 0.0546875
# Jaccard similarity between 1 and 31399: 0.1171875
# Jaccard similarity between 1 and 31411: 0.046875
# Jaccard similarity between 1 and 31415: 0.046875
# Jaccard similarity between 1 and 31418: 0.046875
# Jaccard similarity between 1 and 31430: 0.046875
# Jaccard similarity between 1 and 31433: 0.0703125
# Jaccard similarity between 1 and 31435: 0.0625
# Jaccard similarity between 1 and 31436: 0.140625
# Jaccard similarity between 1 and 31449: 0.09375
# Jaccard similarity between 1 and 31452: 0.1015625
# Jaccard similarity between 1 and 31453: 0.1015625
# Jaccard similarity between 1 and 31460: 0.0859375
# Jaccard similarity between 1 and 31463: 0.0859375
# Jaccard similarity between 1 and 31465: 0.140625
# Jaccard similarity between 1 and 31469: 0.125
# Jaccard similarity between 1 and 31477: 0.046875
# Jaccard similarity between 1 and 31487: 0.0703125
# Jaccard similarity between 1 and 31491: 0.0703125
# Jaccard similarity between 1 and 31494: 0.078125
# Jaccard similarity between 1 and 31496: 0.1328125
# Jaccard similarity between 1 and 31504: 0.0625
# Jaccard similarity between 1 and 31506: 0.0703125
# Jaccard similarity between 1 and 31522: 0.046875
# Jaccard similarity between 1 and 31527: 0.0625
# Jaccard similarity between 1 and 31549: 0.046875
# Jaccard similarity between 1 and 31583: 0.0234375
# Jaccard similarity between 1 and 31590: 0.21875
# Jaccard similarity between 1 and 31606: 0.046875
# Jaccard similarity between 1 and 31607: 0.0625
# Jaccard similarity between 1 and 31608: 0.0546875
# Jaccard similarity between 1 and 31609: 0.09375
# Jaccard similarity between 1 and 31634: 0.1484375
# Jaccard similarity between 1 and 31636: 0.0625
# Jaccard similarity between 1 and 31649: 0.0625
# Jaccard similarity between 1 and 31658: 0.0703125
# Jaccard similarity between 1 and 31660: 0.0703125
# Jaccard similarity between 1 and 31665: 0.0859375
# Jaccard similarity between 1 and 31672: 0.046875
# Jaccard similarity between 1 and 31675: 0.0390625
# Jaccard similarity between 1 and 31684: 0.0703125
# Jaccard similarity between 1 and 31698: 0.109375
# Jaccard similarity between 1 and 31699: 0.0703125
# Jaccard similarity between 1 and 31704: 0.109375
# Jaccard similarity between 1 and 31705: 0.09375
# Jaccard similarity between 1 and 31709: 0.1015625
# Jaccard similarity between 1 and 31717: 0.1015625
# Jaccard similarity between 1 and 31729: 0.0390625
# Jaccard similarity between 1 and 31737: 0.078125
# Jaccard similarity between 1 and 31746: 0.09375
# Jaccard similarity between 1 and 31758: 0.046875
# Jaccard similarity between 1 and 31770: 0.0859375
# Jaccard similarity between 1 and 31782: 0.0859375
# Jaccard similarity between 1 and 31789: 0.0859375
# Jaccard similarity between 1 and 31803: 0.09375
# Jaccard similarity between 1 and 31821: 0.078125
# Jaccard similarity between 1 and 31823: 0.0546875
# Jaccard similarity between 1 and 31836: 0.0546875
# Jaccard similarity between 1 and 31844: 0.09375
# Jaccard similarity between 1 and 31847: 0.1328125
# Jaccard similarity between 1 and 31857: 0.078125
# Jaccard similarity between 1 and 31858: 0.0859375
# Jaccard similarity between 1 and 31859: 0.0859375
# Jaccard similarity between 1 and 31871: 0.046875
# Jaccard similarity between 1 and 31880: 0.1171875
# Jaccard similarity between 1 and 31893: 0.125
# Jaccard similarity between 1 and 31894: 0.0546875
# Jaccard similarity between 1 and 31899: 0.109375
# Jaccard similarity between 1 and 31900: 0.09375
# Jaccard similarity between 1 and 31915: 0.1015625
# Jaccard similarity between 1 and 31919: 0.1328125
# Jaccard similarity between 1 and 31921: 0.109375
# Jaccard similarity between 1 and 31978: 0.0859375
# Jaccard similarity between 1 and 31982: 0.0703125
# Jaccard similarity between 1 and 31992: 0.046875
# Jaccard similarity between 1 and 31993: 0.09375
# Jaccard similarity between 1 and 32000: 0.0625
# Jaccard similarity between 1 and 32001: 0.03125
# Jaccard similarity between 1 and 32003: 0.0703125
# Jaccard similarity between 1 and 32013: 0.09375
# Jaccard similarity between 1 and 32017: 0.09375
# Jaccard similarity between 1 and 32022: 0.0625
# Jaccard similarity between 1 and 32024: 0.1171875
# Jaccard similarity between 1 and 32034: 0.1015625
# Jaccard similarity between 1 and 32081: 0.0703125
# Jaccard similarity between 1 and 32086: 0.078125
# Jaccard similarity between 1 and 32087: 0.078125
# Jaccard similarity between 1 and 32096: 0.1171875
# Jaccard similarity between 1 and 32134: 0.0703125
# Jaccard similarity between 1 and 32151: 0.078125
# Jaccard similarity between 1 and 32154: 0.1015625
# Jaccard similarity between 1 and 32155: 0.0625
# Jaccard similarity between 1 and 32160: 0.078125
# Jaccard similarity between 1 and 32168: 0.09375
# Jaccard similarity between 1 and 32192: 0.1171875
# Jaccard similarity between 1 and 32204: 0.078125
# Jaccard similarity between 1 and 32225: 0.1484375
# Jaccard similarity between 1 and 32233: 0.0703125
# Jaccard similarity between 1 and 32237: 0.0859375
# Jaccard similarity between 1 and 32243: 0.0703125
# Jaccard similarity between 1 and 32248: 0.0546875
# Jaccard similarity between 1 and 32257: 0.078125
# Jaccard similarity between 1 and 32258: 0.09375
# Jaccard similarity between 1 and 32265: 0.109375
# Jaccard similarity between 1 and 32290: 0.078125
# Jaccard similarity between 1 and 32293: 0.0546875
# Jaccard similarity between 1 and 32299: 0.0546875
# Jaccard similarity between 1 and 32321: 0.0625
# Jaccard similarity between 1 and 32332: 0.0546875
# Jaccard similarity between 1 and 32338: 0.0703125
# Jaccard similarity between 1 and 32354: 0.1171875
# Jaccard similarity between 1 and 32355: 0.109375
# Jaccard similarity between 1 and 32362: 0.09375
# Jaccard similarity between 1 and 32364: 0.03125
# Jaccard similarity between 1 and 32365: 0.0703125
# Jaccard similarity between 1 and 32371: 0.0546875
# Jaccard similarity between 1 and 32384: 0.0859375
# Jaccard similarity between 1 and 32389: 0.09375
# Jaccard similarity between 1 and 32393: 0.078125
# Jaccard similarity between 1 and 32410: 0.0625
# Jaccard similarity between 1 and 32413: 0.0390625
# Jaccard similarity between 1 and 32454: 0.078125
# Jaccard similarity between 1 and 32462: 0.0390625
# Jaccard similarity between 1 and 32469: 0.0546875
# Jaccard similarity between 1 and 32481: 0.1015625
# Jaccard similarity between 1 and 32543: 0.1328125
# Jaccard similarity between 1 and 32545: 0.125
# Jaccard similarity between 1 and 32559: 0.0859375
# Jaccard similarity between 1 and 32567: 0.0625
# Jaccard similarity between 1 and 32569: 0.09375
# Jaccard similarity between 1 and 32580: 0.0625
# Jaccard similarity between 1 and 32586: 0.125
# Jaccard similarity between 1 and 32637: 0.125
# Jaccard similarity between 1 and 32645: 0.0625
# Jaccard similarity between 1 and 32655: 0.1328125
# Jaccard similarity between 1 and 32657: 0.078125
# Jaccard similarity between 1 and 32659: 0.078125
# Jaccard similarity between 1 and 32662: 0.09375
# Jaccard similarity between 1 and 32700: 0.1328125
# Jaccard similarity between 1 and 32701: 0.078125
# Jaccard similarity between 1 and 32724: 0.078125
# Jaccard similarity between 1 and 32729: 0.0546875
# Jaccard similarity between 1 and 32739: 0.1015625
# Jaccard similarity between 1 and 32741: 0.109375
# Jaccard similarity between 1 and 32751: 0.078125

# %% [markdown]
# Lidt mærkeligt at der er similarity scores på under threshold. Noget med at den minimerer false negatives og false positives.
#
# *(The Jaccard similarity threshold between 0.0 and1.0. The initialized MinHash LSH will be optimized for the threshold by minizing the false positive and false negative.)*

# %%
def run_or_read_jaccard(run: bool, df_minhash, dict_lsh, threshold):
    if run:
        jaccard_similarities = {}

        for idx, similar_indices in tqdm(dict_lsh.items()):
            for similar_idx in similar_indices:
                if idx < similar_idx:  # Avoid duplicate pairs and self-comparison
                    jaccard_score = df_minhash['minhash'][idx].jaccard(df_minhash['minhash'][similar_idx])
                    jaccard_similarities[(idx, similar_idx)] = jaccard_score

        with open(f'data/jaccard_similarities_{threshold}.pkl', 'wb') as f:
            pickle.dump(jaccard_similarities, f)
        print("Jaccard similarities saved to 'data/jaccard_similarities.pkl'")
    else:
        with open(f'data/jaccard_similarities.pkl_{threshold}', 'rb') as f:
            jaccard_similarities = pickle.load(f)
        print("Jaccard similarities loaded from 'data/jaccard_similarities.pkl'")
    return jaccard_similarities


jaccard_similarities = run_or_read_jaccard(True, df_minhash, dict_lsh, threshold)
# Out:
# 100%|██████████| 51860/51860 [00:10<00:00, 5055.31it/s]
# Jaccard similarities saved to 'data/jaccard_similarities.pkl'
