# %% [markdown]
# # Graph based approach
#
# This notebook is a combination of multiple scripts, that have run independtly and have been combined to a single notebook, to make it easier to read. The scripts were coded independently, so they were easy to run on DTU's HPC environment.

# %% [markdown]
# ## Imports

# %%
import networkx as nx
import pandas as pd
import pickle
import numpy as np
from collections import defaultdict
from sklearn.model_selection import train_test_split
from tqdm import tqdm
import pyarrow as pa
from itertools import combinations
from joblib import Parallel, delayed
import matplotlib.pyplot as plt

# %% [markdown]
# ## Generating the graph

# %%
ratings = pd.read_csv("data/ml-32m/ratings.csv")
movie_descs = pd.read_csv("data/movies_with_description.csv")

# Filter all ratings that not in movie_descs

ratings = ratings[ratings["movieId"].isin(movie_descs["movieId"])]

# Remove all ratings that are less than 5
ratings_filtered = ratings.query("rating > 4")


# Create an edgelist from the dataframe
edges = defaultdict(lambda: 0)

# Group movies by user
movies_per_user = ratings_filtered.groupby("userId").apply(
    lambda x: x["movieId"].values
)

# Create a function that can process the movies for a user independently
def process_movies(movies):
    local_edges = defaultdict(lambda: 0)
    for movie1, movie2 in combinations(movies, 2):
        key = tuple(sorted((movie1, movie2)))
        local_edges[key] += 1
    return local_edges

# Process the movies in parallel
results = Parallel(n_jobs=-1)(
    delayed(process_movies)(movies)
    for movies in tqdm(movies_per_user, desc="Creating edges")
)

# Combine the results
for local_edges in tqdm(results, desc="Combining results"):
    for key, value in local_edges.items():
        edges[key] += value

# Convert the edges to a pyarrow table
print("Save the edges to a parquet file")

edges_table = pa.Table.from_pandas(
    pd.DataFrame(
        [
            {"movie1": key[0], "movie2": key[1], "weight": value}
            for key, value in edges.items()
        ]
    )
)

# Save the table to a file
edges_table.to_pandas().to_parquet("data/edges-movie-all.parquet")

# %% [markdown]
# ## Converting the edges to a NetworkX graph

# %%
edgelist = pd.read_parquet("data/edges-movie-all.parquet")
# Create a graph from the edgelist
G = nx.Graph()

total = len(edgelist)

for _, row in tqdm(edgelist.iterrows(), total=total):
    G.add_edge(row["movie1"], row["movie2"], weight=row["weight"])

with open("data/movie_graph.pickle", "wb") as f:
    pickle.dump(G, f)

# %% [markdown]
# ## Predicting with the graph

# %% [markdown]
# ### Function for predicting movies for a user

# %%
def predict_movies(
    G: nx.Graph,
    user_watched_movies: list[int],
    weighted: bool = True,
    combination: bool = False,
):
    """
    Predicts movies for a user based on their watched movies and a graph of movie relationships.

    Args:
        G: Graph representing movie relationships. Each edge can have a weight.
        user_watched_movies: List of movies watched by the user.
        weighted: Boolean indicating whether predictions should consider edge weights.

    Returns:
        A sorted list of recommended movie IDs based on their predicted relevance.
    """
    # Use a single dictionary for neighbor counts or weights
    recommendations = defaultdict(float)
    recommendations_weighted = defaultdict(float)

    # Iterate over each watched movie and process its neighbors
    for movie in user_watched_movies:
        for neighbor, edge_attrs in G.adj[movie].items():
            if neighbor not in user_watched_movies:
                weight = edge_attrs.get("weight", 1)
                recommendations[neighbor] += 1
                recommendations_weighted[neighbor] += weight

    # Convert recommendations to a DataFrame and sort by the chosen metric
    predictions = (
        pd.DataFrame.from_dict(recommendations, orient="index")
        .reset_index()
        .rename(columns={"index": "movieId", 0: "count"})
        .sort_values(by="count", ascending=False)
    )

    predictions_weighted = (
        pd.DataFrame.from_dict(recommendations, orient="index")
        .reset_index()
        .rename(columns={"index": "movieId", 0: "weight"})
        .sort_values(by="weight", ascending=False)
    )

    if combination:
        new_predictions = predictions.merge(
            predictions_weighted, on="movieId", how="inner"
        )

        new_predictions["combined"] = (
            np.log(new_predictions["count"]) * new_predictions["weight"]
        )

        return new_predictions.sort_values(by="combined", ascending=False)[
            "movieId"
        ].tolist()

    if weighted:
        return predictions_weighted["movieId"].tolist()

    return predictions["movieId"].tolist()

# %% [markdown]
# ### Using the function to predict movies for the user subset

# %%
print("Loading graph...", flush=True)
with open("data/movie_graph.pickle", "rb") as f:
    G = pickle.load(f)
print("Graph loaded!", flush=True)


print("Loading data...", flush=True)
ratings = pd.read_csv("data/ml-32m/ratings.csv")
movie_descs = pd.read_csv("data/movies_with_description.csv")
ratings = ratings[ratings["movieId"].isin(movie_descs["movieId"])]
ratings = ratings[ratings["rating"] >= 5.0]
print("Data loaded!", flush=True)


print("Analysing predetermined users...", flush=True)
users_to_analyze = [304, 6741, 147001]

preds = {u: [] for u in users_to_analyze}
preds_weighted = {u: [] for u in users_to_analyze}
preds_combined = {u: [] for u in users_to_analyze}

for user in users_to_analyze:
    movies_watched = ratings[ratings["userId"] == user]["movieId"].tolist()

    preds[user] = predict_movies(G, movies_watched, weighted=True)
    preds_weighted[user] = predict_movies(G, movies_watched, weighted=True)
    preds_combined[user] = predict_movies(G, movies_watched, combination=True)

with open("data/predictions.pickle", "wb") as f:
    pickle.dump(preds, f)

with open("data/predictions_weighted.pickle", "wb") as f:
    pickle.dump(preds_weighted, f)

with open("data/predictions_combined.pickle", "wb") as f:
    pickle.dump(preds_combined, f)

print("Predictions saved!", flush=True)

# %% [markdown]
# ## Evaluating the predictions

# %%
# Load the movies and ratings
ratings = pd.read_csv("data/ml-32m/ratings.csv")
movie_descs = pd.read_csv("data/movies_with_description.csv")
ratings = ratings[ratings["movieId"].isin(movie_descs["movieId"])]
ratings = ratings[ratings["rating"] >= 5.0]

# Load the predictions for the predetermined users
with open("data/predictions_weighted.pickle", "rb") as f:
    preds_weighted = pickle.load(f)

with open("data/predictions_combined.pickle", "rb") as f:
    preds_combined = pickle.load(f)

with open("data/predictions.pickle", "rb") as f:
    preds = pickle.load(f)

# %% [markdown]
# ### Functions for displaying the predictions

# %%
def get_movies_watched_for_user(user_id):
    movieIds = ratings[ratings["userId"] == user_id]["movieId"].values

    return movie_descs[movie_descs["movieId"].isin(movieIds)]

def get_movie_by_ids(movie_ids: list[int]):
    return movie_descs[movie_descs["movieId"].isin(movie_ids)]

# %% [markdown]
# ### Displaying the predictions

# %%
for user_id in preds_weighted.keys():
    print("Results for user", user_id)
    predicted_movies_for_user = preds_combined[user_id]

    movies_watched = get_movies_watched_for_user(user_id)

    print("Movies watched by user:")
    display(movies_watched)

    print("Movies recommended to user:")
    display(get_movie_by_ids(predicted_movies_for_user[:20]))
# Out:
# Results for user 304
# Movies watched by user:
#       movieId                       title                          genres  \
# 33         50  Usual Suspects, The (1995)          Crime|Mystery|Thriller
# 334       527     Schindler's List (1993)                       Drama|War
# 747      1200               Aliens (1986)  Action|Adventure|Horror|Sci-Fi
# 3378     5010      Black Hawk Down (2001)                Action|Drama|War
# 5616     8914               Primer (2004)                    Drama|Sci-Fi
# 7314    44191       V for Vendetta (2006)     Action|Sci-Fi|Thriller|IMAX
# 7584    48043        Fountain, The (2006)           Drama|Fantasy|Romance
# 8368    58559     Dark Knight, The (2008)         Action|Crime|Drama|IMAX
#
#       imdbId   tmdbId      id  \
# 33    114814    629.0  114814
# 334   108052    424.0  108052
# 747    90605    679.0   90605
# 3378  265086    855.0  265086
# 5616  390384  14337.0  390384
# 7314  434409    752.0  434409
# 7584  414993   1381.0  414993
# 8368  468569    155.0  468569
#
#                                             description
# 33    A sole survivor tells of the twisty events lea...
# 334   In German-occupied Poland during World War II,...
# 747   Fifty-seven years after surviving an apocalypt...
# 3378  The story of 160 elite U.S. soldiers who dropp...
# 5616  Four friends/fledgling entrepreneurs, knowing ...
# 7314  In a future British dystopian society, a shado...
# 7584  As a modern-day scientist, Tommy is struggling...
# 8368  When the menace known as the Joker wreaks havo...
# Movies recommended to user:
#        movieId                                              title  \
# 0            1                                   Toy Story (1995)
# 2            6                                        Heat (1995)
# 305        480                               Jurassic Park (1993)
# 454        733                                   Rock, The (1996)
# 480        780               Independence Day (a.k.a. ID4) (1996)
# 709       1136             Monty Python and the Holy Grail (1975)
# 744       1197                         Princess Bride, The (1987)
# 745       1198  Raiders of the Lost Ark (Indiana Jones and the...
# 794       1262                           Great Escape, The (1963)
# 819       1291          Indiana Jones and the Last Crusade (1989)
# 988       1580                   Men in Black (a.k.a. MIB) (1997)
# 1048      1676                           Starship Troopers (1997)
# 1410      2212                  Man Who Knew Too Much, The (1934)
# 1729      2683       Austin Powers: The Spy Who Shagged Me (1999)
# 1979      3052                                       Dogma (1999)
# 3522      5218                                     Ice Age (2002)
# 3744      5541                                  Hot Shots! (1991)
# 8092     54995                               Planet Terror (2007)
# 16381   122904                                    Deadpool (2016)
# 28524   168252                                       Logan (2017)
#
#                                             genres   imdbId    tmdbId  \
# 0      Adventure|Animation|Children|Comedy|Fantasy   114709     862.0
# 2                            Action|Crime|Thriller   113277     949.0
# 305               Action|Adventure|Sci-Fi|Thriller   107290     329.0
# 454                      Action|Adventure|Thriller   117500    9802.0
# 480               Action|Adventure|Sci-Fi|Thriller   116629     602.0
# 709                       Adventure|Comedy|Fantasy    71853     762.0
# 744        Action|Adventure|Comedy|Fantasy|Romance    93779    2493.0
# 745                               Action|Adventure    82971      85.0
# 794                     Action|Adventure|Drama|War    57115    5925.0
# 819                               Action|Adventure    97576      89.0
# 988                           Action|Comedy|Sci-Fi   119654     607.0
# 1048                                 Action|Sci-Fi   120201     563.0
# 1410                                Drama|Thriller    25452    8208.0
# 1729                       Action|Adventure|Comedy   145660     817.0
# 1979                      Adventure|Comedy|Fantasy   120655    1832.0
# 3522           Adventure|Animation|Children|Comedy   268380     425.0
# 3744                     Action|Comedy|Romance|War   102059    9595.0
# 8092                          Action|Horror|Sci-Fi  1077258    1992.0
# 16381               Action|Adventure|Comedy|Sci-Fi  1431045  293660.0
# 28524                                Action|Sci-Fi  3315342  263115.0
#
#             id                                        description
# 0       114709  A cowboy doll is profoundly threatened and jea...
# 2       113277  A group of high-end professional thieves start...
# 305     107290  A pragmatic paleontologist touring an almost c...
# 454     117500  A mild-mannered chemist and an ex-con must lea...
# 480     116629  The aliens are coming and their goal is to inv...
# 709      71853  King Arthur and his Knights of the Round Table...
# 744      93779  While home sick in bed, a young boy's grandfat...
# 745      82971  In 1936, archaeologist and adventurer Indiana ...
# 794      57115  Allied prisoners of war plan for several hundr...
# 819      97576  In 1938, after his father Professor Henry Jone...
# 988     119654  A police officer joins a secret organization t...
# 1048    120201  Humans in a fascist, militaristic future wage ...
# 1410     25452  An ordinary British couple vacationing in Swit...
# 1729    145660  Dr. Evil is back and has invented a new time m...
# 1979    120655  An abortion clinic worker with a special herit...
# 3522    268380  The story revolves around sub-zero heroes: a w...
# 3744    102059  A parody of Top Gun (1986) in which a talented...
# 8092   1077258  After an experimental bio-weapon is released, ...
# 16381  1431045  A wisecracking mercenary gets experimented on ...
# 28524  3315342  In a future where mutants are nearly extinct, ...
# Results for user 6741
# Movies watched by user:
#       movieId                                              title  \
# 33         50                         Usual Suspects, The (1995)
# 709      1136             Monty Python and the Holy Grail (1975)
# 745      1198  Raiders of the Lost Ark (Indiana Jones and the...
# 760      1215                            Army of Darkness (1993)
# 802      1270                          Back to the Future (1985)
# 819      1291          Indiana Jones and the Last Crusade (1989)
# 1011     1610                   Hunt for Red October, The (1990)
# 1262     2028                         Saving Private Ryan (1998)
# 2037     3147                             Green Mile, The (1999)
# 2670     4011                                      Snatch (2000)
# 3366     4993  Lord of the Rings: The Fellowship of the Ring,...
# 4031     5952      Lord of the Rings: The Two Towers, The (2002)
# 4310     6377                                Finding Nemo (2003)
# 4831     7153  Lord of the Rings: The Return of the King, The...
#
#                                       genres  imdbId  tmdbId      id  \
# 33                    Crime|Mystery|Thriller  114814   629.0  114814
# 709                 Adventure|Comedy|Fantasy   71853   762.0   71853
# 745                         Action|Adventure   82971    85.0   82971
# 760   Action|Adventure|Comedy|Fantasy|Horror  106308   766.0  106308
# 802                  Adventure|Comedy|Sci-Fi   88763   105.0   88763
# 819                         Action|Adventure   97576    89.0   97576
# 1011               Action|Adventure|Thriller   99810  1669.0   99810
# 1262                        Action|Drama|War  120815   857.0  120815
# 2037                             Crime|Drama  120689   497.0  120689
# 2670                   Comedy|Crime|Thriller  208092   107.0  208092
# 3366                       Adventure|Fantasy  120737   120.0  120737
# 4031                       Adventure|Fantasy  167261   121.0  167261
# 4310     Adventure|Animation|Children|Comedy  266543    12.0  266543
# 4831          Action|Adventure|Drama|Fantasy  167260   122.0  167260
#
#                                             description
# 33    A sole survivor tells of the twisty events lea...
# 709   King Arthur and his Knights of the Round Table...
# 745   In 1936, archaeologist and adventurer Indiana ...
# 760   A sardonic hardware store clerk is accidentall...
# 802   Marty McFly, a 17-year-old high school student...
# 819   In 1938, after his father Professor Henry Jone...
# 1011  In November 1984, the Soviet Union's best subm...
# 1262  Following the Normandy Landings, a group of U....
# 2037  The lives of guards on Death Row are affected ...
# 2670  Unscrupulous boxing promoters, violent bookmak...
# 3366  A meek Hobbit from the Shire and eight compani...
# 4031  While Frodo and Sam edge closer to Mordor with...
# 4310  After his son is captured in the Great Barrier...
# 4831  Gandalf and Aragorn lead the World of Men agai...
# Movies recommended to user:
#        movieId                                              title  \
# 20          32          Twelve Monkeys (a.k.a. 12 Monkeys) (1995)
# 31          47                        Seven (a.k.a. Se7en) (1995)
# 181        293  Léon: The Professional (a.k.a. The Professiona...
# 215        353                                   Crow, The (1994)
# 673       1079                        Fish Called Wanda, A (1988)
# 681       1089                              Reservoir Dogs (1992)
# 682       1090                                     Platoon (1986)
# 747       1200                                      Aliens (1986)
# 1836      2843  Black Cat, White Cat (Crna macka, beli macor) ...
# 1946      2997                        Being John Malkovich (1999)
# 4424      6539  Pirates of the Caribbean: The Curse of the Bla...
# 4649      6874                           Kill Bill: Vol. 1 (2003)
# 4894      7254                        The Butterfly Effect (2004)
# 5006      7438                           Kill Bill: Vol. 2 (2004)
# 5022      7475                                        Raid (2003)
# 6597     31696                                 Constantine (2005)
# 6712     32587                                    Sin City (2005)
# 6936     34405                                    Serenity (2005)
# 8092     54995                               Planet Terror (2007)
# 11309    89745                               Avengers, The (2012)
#
#                                         genres   imdbId   tmdbId       id  \
# 20                     Mystery|Sci-Fi|Thriller   114746     63.0   114746
# 31                            Mystery|Thriller   114369    807.0   114369
# 181                Action|Crime|Drama|Thriller   110413    101.0   110413
# 215              Action|Crime|Fantasy|Thriller   109506   9495.0   109506
# 673                               Comedy|Crime    95159    623.0    95159
# 681                     Crime|Mystery|Thriller   105236    500.0   105236
# 682                                  Drama|War    91763    792.0    91763
# 747             Action|Adventure|Horror|Sci-Fi    90605    679.0    90605
# 1836                            Comedy|Romance   118843   1075.0   118843
# 1946                      Comedy|Drama|Fantasy   120601    492.0   120601
# 4424           Action|Adventure|Comedy|Fantasy   325980     22.0   325980
# 4649                     Action|Crime|Thriller   266697     24.0   266697
# 4894                     Drama|Sci-Fi|Thriller   289879   1954.0   289879
# 5006                     Action|Drama|Thriller   378194    393.0   378194
# 5022               Action|Crime|Drama|Thriller   330802  20375.0   330802
# 6597            Action|Fantasy|Horror|Thriller   360486    561.0   360486
# 6712   Action|Crime|Film-Noir|Mystery|Thriller   401792    187.0   401792
# 6936                   Action|Adventure|Sci-Fi   379786  16320.0   379786
# 8092                      Action|Horror|Sci-Fi  1077258   1992.0  1077258
# 11309             Action|Adventure|Sci-Fi|IMAX   848228  24428.0   848228
#
#                                              description
# 20     In a future world devastated by disease, a con...
# 31     Two detectives, a rookie and a veteran, hunt a...
# 181    12-year-old Mathilda is reluctantly taken in b...
